# %% [markdown]
# **Задание 0. Загрузите необходимые библиотеки**

# %%
import re
import spacy
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

# %% [markdown]
# **Задание 1. Загрузка данных**

# %% [markdown]
# Вставьте текст для обработки согласно вашему варианту

# %%
text = """В 2023 году КПД солнечных батарей на основе перовскита достиг рекордных 29,8%, что всего на 3,2% меньше теоретического максимума!
Технология Perovskite Solar Cells (PSC) позволяет создавать гибкие, полупрозрачные панели стоимостью 0,25/Вт—в3разадешевлекремниевыханалогов.
Ветрогенераторы нового поколения с системой SMARTBlade оптимизируют аэродинамику в реальном времени,повышая выработку на 18 млрд, который к 2030 году обеспечит 40% потребностей страны в электроэнергии.
Технология V2G (Vehicle-to-Grid) позволяет электромобилям не только потреблять, но и возвращать энергию в сеть, формируя распределённую систему хранения.
Эффективность современных Li-ion аккумуляторов превысила 95%, а их стоимость упала до $100/кВт⋅ч, сделав возобновляемую энергетику конкурентоспособной даже без государственных субсидий."""


print(text)
# Out:
# В 2023 году КПД солнечных батарей на основе перовскита достиг рекордных 29,8%, что всего на 3,2% меньше теоретического максимума!
# Технология Perovskite Solar Cells (PSC) позволяет создавать гибкие, полупрозрачные панели стоимостью 0,25/Вт—в3разадешевлекремниевыханалогов.
# Ветрогенераторы нового поколения с системой SMARTBlade оптимизируют аэродинамику в реальном времени,повышая выработку на 18 млрд, который к 2030 году обеспечит 40% потребностей страны в электроэнергии.
# Технология V2G (Vehicle-to-Grid) позволяет электромобилям не только потреблять, но и возвращать энергию в сеть, формируя распределённую систему хранения.
# Эффективность современных Li-ion аккумуляторов превысила 95%, а их стоимость упала до $100/кВт⋅ч, сделав возобновляемую энергетику конкурентоспособной даже без государственных субсидий.

# %% [markdown]
# **Задание 2. Нормализация текста.**

# %% [markdown]
# Приведите текст к нижнему регистру, удалите лишние пробоелы, переносы строк, спецсимволы, пунктуацию, обработайте цифры.

# %%
# ваш код
import re
import string


text = text.lower()
text = text.replace('ё', 'е')
text = text.replace('\n', ' ')

text = text.translate(str.maketrans('', '', string.punctuation))
quotes_to_remove = ['«', '»', '„', '“', '”', '‘', '’', '—', '°', '⋅']
for quote in quotes_to_remove:
    text = text.replace(quote, ' ')

text = re.sub(r'\d+', ' ', text)
text = re.sub(r'\s+', ' ', text).strip()

normalized_text = text
print(normalized_text)
# Out:
# в году кпд солнечных батарей на основе перовскита достиг рекордных что всего на меньше теоретического максимума технология perovskite solar cells psc позволяет создавать гибкие полупрозрачные панели стоимостью вт в разадешевлекремниевыханалогов ветрогенераторы нового поколения с системой smartblade оптимизируют аэродинамику в реальном времениповышая выработку на млрд который к году обеспечит потребностей страны в электроэнергии технология v g vehicletogrid позволяет электромобилям не только потреблять но и возвращать энергию в сеть формируя распределенную систему хранения эффективность современных liion аккумуляторов превысила а их стоимость упала до квт ч сделав возобновляемую энергетику конкурентоспособной даже без государственных субсидий

# %% [markdown]
# **Задание 3. Токенизация**

# %% [markdown]
# Токенизируйте текст.

# %%
# ваш код
tokens = normalized_text.split()


print(f"Токены: {tokens}\n")
# Out:
# Токены: ['в', 'году', 'кпд', 'солнечных', 'батарей', 'на', 'основе', 'перовскита', 'достиг', 'рекордных', 'что', 'всего', 'на', 'меньше', 'теоретического', 'максимума', 'технология', 'perovskite', 'solar', 'cells', 'psc', 'позволяет', 'создавать', 'гибкие', 'полупрозрачные', 'панели', 'стоимостью', 'вт', 'в', 'разадешевлекремниевыханалогов', 'ветрогенераторы', 'нового', 'поколения', 'с', 'системой', 'smartblade', 'оптимизируют', 'аэродинамику', 'в', 'реальном', 'времениповышая', 'выработку', 'на', 'млрд', 'который', 'к', 'году', 'обеспечит', 'потребностей', 'страны', 'в', 'электроэнергии', 'технология', 'v', 'g', 'vehicletogrid', 'позволяет', 'электромобилям', 'не', 'только', 'потреблять', 'но', 'и', 'возвращать', 'энергию', 'в', 'сеть', 'формируя', 'распределенную', 'систему', 'хранения', 'эффективность', 'современных', 'liion', 'аккумуляторов', 'превысила', 'а', 'их', 'стоимость', 'упала', 'до', 'квт', 'ч', 'сделав', 'возобновляемую', 'энергетику', 'конкурентоспособной', 'даже', 'без', 'государственных', 'субсидий']

# %% [markdown]
# **Задание 4. Удаление стоп-слов**

# %% [markdown]
# Выведите 2 списка - 1. Очищенных токенов, 2. Список удаленных стоп-слов

# %%
# ваш код
def remove_stopwords(tokens):
    russian_stopwords = set(stopwords.words('russian'))
    stopwords_list = []
    cleaned_tokens = []

    for token in tokens:
        if token in russian_stopwords:
            stopwords_list.append(token)
        else:
            cleaned_tokens.append(token)

    return cleaned_tokens, stopwords_list

cleaned_tokens, removed_stopwords = remove_stopwords(tokens)

print(f"Количество очищенных токенов: {cleaned_tokens} ")
print(cleaned_tokens)
print("\n")
print(f"Удалённые стоп-слова: {removed_stopwords}")
# Out:
# Количество очищенных токенов: ['году', 'кпд', 'солнечных', 'батарей', 'основе', 'перовскита', 'достиг', 'рекордных', 'меньше', 'теоретического', 'максимума', 'технология', 'perovskite', 'solar', 'cells', 'psc', 'позволяет', 'создавать', 'гибкие', 'полупрозрачные', 'панели', 'стоимостью', 'вт', 'разадешевлекремниевыханалогов', 'ветрогенераторы', 'нового', 'поколения', 'системой', 'smartblade', 'оптимизируют', 'аэродинамику', 'реальном', 'времениповышая', 'выработку', 'млрд', 'который', 'году', 'обеспечит', 'потребностей', 'страны', 'электроэнергии', 'технология', 'v', 'g', 'vehicletogrid', 'позволяет', 'электромобилям', 'потреблять', 'возвращать', 'энергию', 'сеть', 'формируя', 'распределенную', 'систему', 'хранения', 'эффективность', 'современных', 'liion', 'аккумуляторов', 'превысила', 'стоимость', 'упала', 'квт', 'ч', 'сделав', 'возобновляемую', 'энергетику', 'конкурентоспособной', 'государственных', 'субсидий']
# ['году', 'кпд', 'солнечных', 'батарей', 'основе', 'перовскита', 'достиг', 'рекордных', 'меньше', 'теоретического', 'максимума', 'технология', 'perovskite', 'solar', 'cells', 'psc', 'позволяет', 'создавать', 'гибкие', 'полупрозрачные', 'панели', 'стоимостью', 'вт', 'разадешевлекремниевыханалогов', 'ветрогенераторы', 'нового', 'поколения', 'системой', 'smartblade', 'оптимизируют', 'аэродинамику', 'реальном', 'времениповышая', 'выработку', 'млрд', 'который', 'году', 'обеспечит', 'потребностей', 'страны', 'электроэнергии', 'технология', 'v', 'g', 'vehicletogrid', 'позволяет', 'электромобилям', 'потреблять', 'возвращать', 'энергию', 'сеть', 'формируя', 'распределенную', 'систему', 'хранения', 'эффективность', 'современных', 'liion', 'аккумуляторов', 'превысила', 'стоимость', 'упала', 'квт', 'ч', 'сделав', 'возобновляемую', 'энергетику', 'конкурентоспособной', 'государственных', 'субсидий']
#
#
# Удалённые стоп-слова: ['в', 'на', 'что', 'всего', 'на', 'в', 'с', 'в', 'на', 'к', 'в', 'не', 'только', 'но', 'и', 'в', 'а', 'их', 'до', 'даже', 'без']

# %% [markdown]
# **Задание 5. Лемматизация и стемминг**

# %% [markdown]
# Примените к токенам алгоритмы лемматизации и стемминга. Выведите 2 списка - 1. Лемматизированные токены 2. Стемматизированные токены

# %%
# ваш код
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer("russian")

lemmatized_tokens = []
for word in filtered_tokens:
    lemma = stemmer.stem(word)
    lemmatized_tokens.append(lemma)


stemmed_tokens = []
for word in filtered_tokens:
    stem = stemmer.stem(word)
    stemmed_tokens.append(stem)


print("Лемматизированные токены:")
print(lemmatized_tokens)

print("\nСтемматизированные токены:")
print(stemmed_tokens)
# Out:
# Лемматизированные токены:
# ['в', 'год', 'кпд', 'солнечн', 'батар', 'на', 'основ', 'перовскит', 'достиг', 'рекордн', 'что', 'всег', 'на', 'меньш', 'теоретическ', 'максимум', 'технолог', 'perovskite', 'solar', 'cells', 'psc', 'позволя', 'создава', 'гибк', 'полупрозрачн', 'панел', 'стоимост', 'вт', 'в', 'разадешевлекремниевыханалог', 'ветрогенератор', 'нов', 'поколен', 'с', 'систем', 'smartblade', 'оптимизир', 'аэродинамик', 'в', 'реальн', 'времениповыш', 'выработк', 'на', 'млрд', 'котор', 'к', 'год', 'обеспеч', 'потребн', 'стран', 'в', 'электроэнерг', 'технолог', 'v', 'g', 'vehicletogrid', 'позволя', 'электромобил', 'не', 'тольк', 'потребля', 'но', 'и', 'возвраща', 'энерг', 'в', 'сет', 'формиру', 'распределен', 'сист', 'хранен', 'эффективн', 'современ', 'liion', 'аккумулятор', 'превыс', 'а', 'их', 'стоимост', 'упа', 'до', 'квт', 'ч', 'сдела', 'возобновля', 'энергетик', 'конкурентоспособн', 'даж', 'без', 'государствен', 'субсид']
#
# Стемматизированные токены:
# ['в', 'год', 'кпд', 'солнечн', 'батар', 'на', 'основ', 'перовскит', 'достиг', 'рекордн', 'что', 'всег', 'на', 'меньш', 'теоретическ', 'максимум', 'технолог', 'perovskite', 'solar', 'cells', 'psc', 'позволя', 'создава', 'гибк', 'полупрозрачн', 'панел', 'стоимост', 'вт', 'в', 'разадешевлекремниевыханалог', 'ветрогенератор', 'нов', 'поколен', 'с', 'систем', 'smartblade', 'оптимизир', 'аэродинамик', 'в', 'реальн', 'времениповыш', 'выработк', 'на', 'млрд', 'котор', 'к', 'год', 'обеспеч', 'потребн', 'стран', 'в', 'электроэнерг', 'технолог', 'v', 'g', 'vehicletogrid', 'позволя', 'электромобил', 'не', 'тольк', 'потребля', 'но', 'и', 'возвраща', 'энерг', 'в', 'сет', 'формиру', 'распределен', 'сист', 'хранен', 'эффективн', 'современ', 'liion', 'аккумулятор', 'превыс', 'а', 'их', 'стоимост', 'упа', 'до', 'квт', 'ч', 'сдела', 'возобновля', 'энергетик', 'конкурентоспособн', 'даж', 'без', 'государствен', 'субсид']

# %% [markdown]
# **Задание 6. Напишите функцию для препроцессинга текста**

# %% [markdown]
# Объедините все шаги в одну функцию. Выведите результат с лемматизированным списком

# %%
def preprocess_text(text, method='lemmatization'):
    text = text.lower()
    text = text.replace('ё', 'е')
    text = text.replace('\n', ' ')

    text = text.translate(str.maketrans('', '', string.punctuation))
    quotes_to_remove = ['«', '»', '„', '“', '”', '‘', '’', '—', '°', '⋅']
    for quote in quotes_to_remove:
        text = text.replace(quote, ' ')

    text = re.sub(r'\d+', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    tokens = text.split()

    russian_stopwords = set(stopwords.words('russian'))

    cleaned_tokens = []
    for token in tokens:
        if token not in russian_stopwords:
            cleaned_tokens.append(token)

    if method == 'lemmatization':
        from nltk.stem import SnowballStemmer

        russian_stemmer = SnowballStemmer("russian")
        english_stemmer = SnowballStemmer("english")

        def detect_language(word):
            ru_letters = 'абвгдежзийклмнопрстуфхцчшщъыьэюя'
            en_letters = 'abcdefghijklmnopqrstuvwxyz'

            has_ru = any(letter in ru_letters for letter in word.lower())
            has_en = any(letter in en_letters for letter in word.lower())

            if has_ru:
                return 'ru'
            elif has_en:
                return 'en'
            else:
                return 'other'

        result = []
        for token in cleaned_tokens:
            lang = detect_language(token)
            if lang == 'ru':
                result.append(russian_stemmer.stem(token))
            elif lang == 'en':
                result.append(english_stemmer.stem(token))
            else:
                result.append(token)

    elif method == 'stemming':
        from nltk.stem import SnowballStemmer

        russian_stemmer = SnowballStemmer("russian")
        english_stemmer = SnowballStemmer("english")

        def detect_language(word):
            ru_letters = 'абвгдежзийклмнопрстуфхцчшщъыьэюя'
            en_letters = 'abcdefghijklmnopqrstuvwxyz'

            has_ru = any(letter in ru_letters for letter in word.lower())
            has_en = any(letter in en_letters for letter in word.lower())

            if has_ru:
                return 'ru'
            elif has_en:
                return 'en'
            else:
                return 'other'

        result = []
        for token in cleaned_tokens:
            lang = detect_language(token)
            if lang == 'ru':
                result.append(russian_stemmer.stem(token))
            elif lang == 'en':
                result.append(english_stemmer.stem(token))
            else:
                result.append(token)
    else:
        result = cleaned_tokens

    return result



text = """В 2023 году КПД солнечных батарей на основе перовскита достиг рекордных 29,8%, что всего на 3,2% меньше теоретического максимума!
Технология Perovskite Solar Cells (PSC) позволяет создавать гибкие, полупрозрачные панели стоимостью 0,25/Вт—в3разадешевлекремниевыханалогов.
Ветрогенераторы нового поколения с системой SMARTBlade оптимизируют аэродинамику в реальном времени,повышая выработку на 18 млрд, который к 2030 году обеспечит 40% потребностей страны в электроэнергии.
Технология V2G (Vehicle-to-Grid) позволяет электромобилям не только потреблять, но и возвращать энергию в сеть, формируя распределённую систему хранения.
Эффективность современных Li-ion аккумуляторов превысила 95%, а их стоимость упала до $100/кВт⋅ч, сделав возобновляемую энергетику конкурентоспособной даже без государственных субсидий."""
result = preprocess_text(text, method='lemmatization')
print(result)
# Out:
# ['год', 'кпд', 'солнечн', 'батар', 'основ', 'перовскит', 'достиг', 'рекордн', 'меньш', 'теоретическ', 'максимум', 'технолог', 'perovskit', 'solar', 'cell', 'psc', 'позволя', 'создава', 'гибк', 'полупрозрачн', 'панел', 'стоимост', 'вт', 'разадешевлекремниевыханалог', 'ветрогенератор', 'нов', 'поколен', 'систем', 'smartblad', 'оптимизир', 'аэродинамик', 'реальн', 'времениповыш', 'выработк', 'млрд', 'котор', 'год', 'обеспеч', 'потребн', 'стран', 'электроэнерг', 'технолог', 'v', 'g', 'vehicletogrid', 'позволя', 'электромобил', 'потребля', 'возвраща', 'энерг', 'сет', 'формиру', 'распределен', 'сист', 'хранен', 'эффективн', 'современ', 'liion', 'аккумулятор', 'превыс', 'стоимост', 'упа', 'квт', 'ч', 'сдела', 'возобновля', 'энергетик', 'конкурентоспособн', 'государствен', 'субсид']
