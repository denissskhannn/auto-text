# %% [markdown]
# **Задание 0. Загрузите необходимые библиотеки**

# %%
import string
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import spacy


nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)
# Out:
# True

# %% [markdown]
# **Задание 1. Загрузка данных**

# %% [markdown]
# Вставьте текст для обработки согласно вашему варианту

# %%
text = "В 2023 году КПД солнечных батарей на основе перовскита достиг рекордных 29,8%, что всего на 3,2% меньше теоретического максимума!Технология Perovskite Solar Cells (PSC) позволяет создавать гибкие, полупрозрачные панели стоимостью 0,25/Вт—в3разадешевлекремниевыханалогов. Ветрогенераторы нового поколения с системой SMARTBlade оптимизируют аэродинамику в реальном времени,повышая выработку на 18 млрд, который к 2030 году обеспечит 40% потребностей страны в электроэнергии. Технология V2G (Vehicle-to-Grid) позволяет электромобилям не только потреблять, но и возвращать энергию в сеть, формируя распределённую систему хранения. Эффективность современных Li-ion аккумуляторов превысила 95%, а их стоимость упала до $100/кВт⋅ч, сделав возобновляемую энергетику конкурентоспособной даже без государственных субсидий."

# %% [markdown]
# **Задание 2. Нормализация текста.**

# %% [markdown]
# Приведите текст к нижнему регистру, удалите лишние пробоелы, переносы строк, спецсимволы, пунктуацию, обработайте цифры.

# %%
def normalize_text(text):

    text = text.lower()

    digits = "1234567890"
    text = ''.join(char for char in text if char not in digits)

    translator = str.maketrans('', '', string.punctuation)
    text = text.translate(translator)

    text = ' '.join(text.split())

    return text

normalized_text = normalize_text(text)
print("Нормализованный текст:", normalized_text)
# Out:
# Нормализованный текст: в году кпд солнечных батарей на основе перовскита достиг рекордных что всего на меньше теоретического максимуматехнология perovskite solar cells psc позволяет создавать гибкие полупрозрачные панели стоимостью вт—вразадешевлекремниевыханалогов ветрогенераторы нового поколения с системой smartblade оптимизируют аэродинамику в реальном времениповышая выработку на млрд который к году обеспечит потребностей страны в электроэнергии технология vg vehicletogrid позволяет электромобилям не только потреблять но и возвращать энергию в сеть формируя распределённую систему хранения эффективность современных liion аккумуляторов превысила а их стоимость упала до квт⋅ч сделав возобновляемую энергетику конкурентоспособной даже без государственных субсидий

# %% [markdown]
# **Задание 3. Токенизация**

# %% [markdown]
# Токенизируйте текст.

# %%
def simple_tokenize(text):

    for punct in string.punctuation:
        text = text.replace(punct, f' {punct} ')

    tokens = [token for token in text.split() if token]

    return tokens


tokens_list = simple_tokenize(normalized_text)
print("Токены:", tokens_list)
# Out:
# Токены: ['в', 'году', 'кпд', 'солнечных', 'батарей', 'на', 'основе', 'перовскита', 'достиг', 'рекордных', 'что', 'всего', 'на', 'меньше', 'теоретического', 'максимуматехнология', 'perovskite', 'solar', 'cells', 'psc', 'позволяет', 'создавать', 'гибкие', 'полупрозрачные', 'панели', 'стоимостью', 'вт—вразадешевлекремниевыханалогов', 'ветрогенераторы', 'нового', 'поколения', 'с', 'системой', 'smartblade', 'оптимизируют', 'аэродинамику', 'в', 'реальном', 'времениповышая', 'выработку', 'на', 'млрд', 'который', 'к', 'году', 'обеспечит', 'потребностей', 'страны', 'в', 'электроэнергии', 'технология', 'vg', 'vehicletogrid', 'позволяет', 'электромобилям', 'не', 'только', 'потреблять', 'но', 'и', 'возвращать', 'энергию', 'в', 'сеть', 'формируя', 'распределённую', 'систему', 'хранения', 'эффективность', 'современных', 'liion', 'аккумуляторов', 'превысила', 'а', 'их', 'стоимость', 'упала', 'до', 'квт⋅ч', 'сделав', 'возобновляемую', 'энергетику', 'конкурентоспособной', 'даже', 'без', 'государственных', 'субсидий']

# %% [markdown]
# **Задание 4. Удаление стоп-слов**

# %% [markdown]
# Выведите 2 списка - 1. Очищенных токенов, 2. Список удаленных стоп-слов

# %%
russian_stopwords = set(stopwords.words('russian'))

clean_tokens = [token for token in tokens_list if token not in russian_stopwords]
removed_stops = [token for token in tokens_list if token in russian_stopwords]

print("Очищенные токены:", clean_tokens)
print("\nУдалённые стоп-слова:", removed_stops)
# Out:
# Очищенные токены: ['году', 'кпд', 'солнечных', 'батарей', 'основе', 'перовскита', 'достиг', 'рекордных', 'меньше', 'теоретического', 'максимуматехнология', 'perovskite', 'solar', 'cells', 'psc', 'позволяет', 'создавать', 'гибкие', 'полупрозрачные', 'панели', 'стоимостью', 'вт—вразадешевлекремниевыханалогов', 'ветрогенераторы', 'нового', 'поколения', 'системой', 'smartblade', 'оптимизируют', 'аэродинамику', 'реальном', 'времениповышая', 'выработку', 'млрд', 'который', 'году', 'обеспечит', 'потребностей', 'страны', 'электроэнергии', 'технология', 'vg', 'vehicletogrid', 'позволяет', 'электромобилям', 'потреблять', 'возвращать', 'энергию', 'сеть', 'формируя', 'распределённую', 'систему', 'хранения', 'эффективность', 'современных', 'liion', 'аккумуляторов', 'превысила', 'стоимость', 'упала', 'квт⋅ч', 'сделав', 'возобновляемую', 'энергетику', 'конкурентоспособной', 'государственных', 'субсидий']
#
# Удалённые стоп-слова: ['в', 'на', 'что', 'всего', 'на', 'с', 'в', 'на', 'к', 'в', 'не', 'только', 'но', 'и', 'в', 'а', 'их', 'до', 'даже', 'без']

# %% [markdown]
# **Задание 5. Лемматизация и стемминг**

# %% [markdown]
# Примените к токенам алгоритмы лемматизации и стемминга. Выведите 2 списка - 1. Лемматизированные токены 2. Стемматизированные токены

# %%
try:
    nlp_ru = spacy.load("ru_core_news_sm")
except OSError:
    print("Downloading spaCy Russian model. This may take a moment...")
    spacy.cli.download("ru_core_news_sm")
    nlp_ru = spacy.load("ru_core_news_sm")


text_for_lemmatization = " ".join(tokens_list)
doc = nlp_ru(text_for_lemmatization)

lemmatized_tokens = [token.lemma_ for token in doc if token.is_alpha]

print("1. Лемматизированные токены:")
print(lemmatized_tokens)

stemmer = SnowballStemmer("russian")
stemmed_tokens = [stemmer.stem(token) for token in tokens_list]

print("\n2. Стемматизированные токены:")
print(stemmed_tokens)
# Out:
# 1. Лемматизированные токены:
# ['в', 'год', 'кпд', 'солнечный', 'батарея', 'на', 'основа', 'перовскит', 'достигнуть', 'рекордный', 'что', 'всего', 'на', 'меньше', 'теоретический', 'максимуматехнология', 'perovskite', 'solar', 'cells', 'psc', 'позволять', 'создавать', 'гибкий', 'полупрозрачный', 'панель', 'стоимость', 'вт', 'вразадешевлекремниевыханалогов', 'ветрогенераторы', 'новый', 'поколение', 'с', 'система', 'smartblade', 'оптимизировать', 'аэродинамика', 'в', 'реальный', 'времениповышая', 'выработка', 'на', 'млрд', 'который', 'к', 'год', 'обеспечить', 'потребность', 'страна', 'в', 'электроэнергия', 'технология', 'vg', 'vehicletogrid', 'позволять', 'электромобиль', 'не', 'только', 'потреблять', 'но', 'и', 'возвращать', 'энергия', 'в', 'сеть', 'формировать', 'распределённый', 'система', 'хранение', 'эффективность', 'современный', 'liion', 'аккумулятор', 'превысить', 'а', 'они', 'стоимость', 'упасть', 'до', 'сделать', 'возобновлять', 'энергетик', 'конкурентоспособный', 'даже', 'без', 'государственный', 'субсидия']
#
# 2. Стемматизированные токены:
# ['в', 'год', 'кпд', 'солнечн', 'батар', 'на', 'основ', 'перовскит', 'достиг', 'рекордн', 'что', 'всег', 'на', 'меньш', 'теоретическ', 'максимуматехнолог', 'perovskite', 'solar', 'cells', 'psc', 'позволя', 'создава', 'гибк', 'полупрозрачн', 'панел', 'стоимост', 'вт—вразадешевлекремниевыханалог', 'ветрогенератор', 'нов', 'поколен', 'с', 'систем', 'smartblade', 'оптимизир', 'аэродинамик', 'в', 'реальн', 'времениповыш', 'выработк', 'на', 'млрд', 'котор', 'к', 'год', 'обеспеч', 'потребн', 'стран', 'в', 'электроэнерг', 'технолог', 'vg', 'vehicletogrid', 'позволя', 'электромобил', 'не', 'тольк', 'потребля', 'но', 'и', 'возвраща', 'энерг', 'в', 'сет', 'формиру', 'распределен', 'сист', 'хранен', 'эффективн', 'современ', 'liion', 'аккумулятор', 'превыс', 'а', 'их', 'стоимост', 'упа', 'до', 'квт⋅ч', 'сдела', 'возобновля', 'энергетик', 'конкурентоспособн', 'даж', 'без', 'государствен', 'субсид']

# %% [markdown]
# **Задание 6. Напишите функцию для препроцессинга текста**

# %% [markdown]
# Объедините все шаги в одну функцию. Выведите результат с лемматизированным списком

# %%
def preprocess_text(raw_text):
    text = raw_text.lower()

    digits = "1234567890"
    text = ''.join(char for char in text if char not in digits)

    translator = str.maketrans('', '', string.punctuation)
    text = text.translate(translator)

    text = ' '.join(text.split())

    normalized_text = text

    tokens_list = []
    for punct in string.punctuation:
        normalized_text = normalized_text.replace(punct, f' {punct} ')
    tokens_list = [token for token in normalized_text.split() if token]


    clean_tokens = [token for token in tokens_list if token not in russian_stopwords]

    text_for_lemmatization = " ".join(clean_tokens)
    doc = nlp_ru(text_for_lemmatization)
    lemmatized_tokens = [token.lemma_ for token in doc if token.is_alpha]

    return lemmatized_tokens

final_lemmatized_list = preprocess_text(text)
print("Лемматизированный список слова:")
print(final_lemmatized_list)
# Out:
# Лемматизированный список слова:
# ['год', 'кпд', 'солнечный', 'батарея', 'основа', 'перовскит', 'достигнуть', 'рекордный', 'меньше', 'теоретический', 'максимуматехнология', 'perovskite', 'solar', 'cells', 'psc', 'позволять', 'создавать', 'гибкий', 'полупрозрачный', 'панель', 'стоимость', 'вт', 'вразадешевлекремниевыханалогов', 'ветрогенераторы', 'новый', 'поколение', 'система', 'smartblade', 'оптимизировать', 'аэродинамика', 'реальном', 'времениповышая', 'выработка', 'млрд', 'который', 'год', 'обеспечить', 'потребность', 'страна', 'электроэнергия', 'технология', 'vg', 'vehicletogrid', 'позволять', 'электромобиль', 'потреблять', 'возвращать', 'энергия', 'сеть', 'формировать', 'распределённый', 'система', 'хранение', 'эффективность', 'современный', 'liion', 'аккумулятор', 'превысить', 'стоимость', 'упасть', 'сделать', 'возобновлять', 'энергетика', 'конкурентоспособный', 'государственный', 'субсидия']
