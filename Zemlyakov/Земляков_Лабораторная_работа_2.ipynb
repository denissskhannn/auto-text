# %% [markdown]
# **Задание 1: Векторизация текста с использованием Мешка слов (BoW) и TF-IDF**

# %% [markdown]
# 1. Создайте корпус из минимум 10 текстовых документов (можно взять новостные статьи, отзывы на товары, статьи по одной тематике).
# 2. Реализуйте предобработку текста, включающую:
# * Приведение к нижнему регистру
# * Токенизацию
# * Удаление стоп-слов и пунктуации
# * Лемматизацию/стемминг
# 3. Реализуйте модель Мешка слов (BoW) с использованием CountVectorizer из scikit-learn.
# 4. Реализуйте модель TF-IDF с использованием TfidfVectorizer из scikit-learn.
# 5. Найдите 10 самых значимых терминов для каждого документа по обоим подходам и сравните результаты.
# 6. Визуализируйте сходство документов с помощью метрики косинусного расстояния для обоих подходов.
# 7. Прокомментируйте разницу в результатах между BoW и TF-IDF

# %%
# 7. Ответ: разница между BoW и TF-IDF заключается в том, что BoW преобразует текстовые документы в числовые векторы, а TF-IDF используется для оценки важности слова
# в документе относительно других документов.

# %%
# ваш код
text_documents = ["""kyousuke to miss Bounty Finals due to visa issues
NucleonZ has gotten the call-up from the academy team and will join Falcons in Malta.

Falcons has announced that Maxim "⁠kyousuke⁠" Lukin will miss the BLAST Bounty Finals in Malta due to "unresolved visa complications", and will not be with the rest of his team as they tackle their first LAN of 2026 from January 22-25.

The Russian rifler, who finished second in the running for Rookie of the Year and landed just shy of a placement on the Top 20 Players of 2025 ranking, posted a 1.28 rating throughout the four maps Falcons played online against ECSTATIC and Monte to help his team qualify for the LAN finals.

Falcons have called upon Matej "⁠NucleonZ⁠" Trajkoski from the academy roster to fill kyousuke's absence, making BLAST Bounty his first event against top-tier opposition after he recorded his first maps on HLTV at Red Bull GIBAWAY JOURNEY in November 2025.

The 18-year-old has been a part of Falcons Force since the academy roster was announced in September 2025 and he posted a 1.13 rating at the aforementioned event in Sweden, joint-highest alongside Vladimir "⁠VENO⁠" Stankovic in Falcons Force's group stage finish. """,




"""NiKo talks G2 departure, sacrificing for kyousuke, and Falcons peak
The Bosnian star reflected on his career so far in an in-depth interview conducted by Freya.


While at the Budapest Major, before the quarter-final clash with Spirit, Nikola "⁠NiKo⁠" Kovač sat down with Freya "⁠Freya⁠" Spiers for an hour-long interview to discuss his journey so far, from his childhood in Brčko, a small city in northern Bosnia and Herzegovina, to his switch to Falcons at the end of 2024 and his expectations for the new season.

The blockbuster move in December 2024 brought an end to one of the most protracted transfer sagas in Counter-Strike history. The Saudi organization had come close to securing NiKo a year earlier, only for him to make a last-minute U-turn and decide to stay with G2.

NiKo revealed that talks with Falcons began before IEM Sydney 2023 and that he started contemplating a move after realizing that G2 were open to his departure.

"As soon as we finished Sydney, I had, like, five days to make a decision if I wanted to join Falcons or not," he revealed.

"I think at first I said yes solely because it felt like G2 didn't show much interest in keeping me on the team. And that kind of hurt me and pushed me into saying yes to Falcons.

"It was just lack of, kind of, interest from their side. They hadn't talked to me much. They were, like, 'This is the offer. You make a decision.' And I was, like, 'Okay, give me some time.'

"And during this period, I don't think there was one time when someone came and asked me if I wanted to stay on the team or not, for example. So that kind of showed me they were fine without me, I guess.

"They hadn't even asked me, like, 'What is the reason for you wanting to leave? Would you like to change something?' So yeah, then I said yes to Falcons."


The lack of certainty regarding tier-one event participation in 2024 — the last year before the VRS system came into effect — made NiKo decide to stay in G2 one more year, completing the move to the Saudi organization only after the Shanghai Major.

NiKo reunited with Ilya "⁠m0NESY⁠" Osipov four months into 2025 as the Russian AWPer also joined from G2, while Maxim "⁠kyousuke⁠" Lukin was signed from Spirit during the summer break.

The 17-year-old's arrival has forced NiKo to give up space on the team and become more of a supportive piece, which had an impact on his performances during the second half of the season.

"I wouldn't give up my roles for many players," he said. "Maxim [kyousuke] is one of the players I would do it for. Maybe him and donk. But I don't think many other players are better than me in those roles.

"My only interest is team results and team success. So I will do everything I can for the team to succeed, basically. This was the only reason I decided to step away and give it to Maxim because I feel this will give us a higher chance to win trophies."

The 2025 season was marked by near-misses at major tournaments, as Falcons came in second place at five events and lifted only one trophy, at PGL Bucharest.

It was a far cry from the lofty expectations that accompanied every big signing, but the Saudi organization decided against making further changes in the off-season, only adding to the backroom staff with the hiring of Aymen "⁠Aymeinstein⁠" Bencheikh as an analyst coach.

NiKo expects Falcons to gun for the biggest trophies in 2026.

"This is definitely the team that we will keep for a long time," he said. "Obviously, I can't see the future, how everything will be, but this team will get time. This team needs to grow together. It feels like we have more than enough firepower.

"I think we have a good core on the team, with Maxim, Ilya [m0NESY] and Damjan [kyxsan] as well, and then René [TeSeS] and me filling the gaps. So I think we are covered. We have a pretty good match when it comes to the roles, and now it's about developing ourselves as a team and also as players. Especially for René and me in some of these roles we have.

"I would say this is the team that can achieve a lot. I think we have been making good progress since IEM Cologne. We have been showing some consistent and quality CS. Now it's about taking it to the next level. I expect to see our peak in the next season." """,



"""nafany, Ax1Le and groove reunite in new team

The former Gambit and Cloud9 trio is working together again in an org-less team with benched players.

A new Russian roster has been created featuring players who have been benched by different teams, Vladislav "⁠nafany⁠" Gorshkov has confirmed on Telegram. The Russian captain is reuniting with his former Gambit and Cloud9 teammate Sergey "⁠Ax1Le⁠" Rykhtorov and coach Konstantin "⁠groove⁠" Pikiner in this project, called TDK.

"Due to the market situation and our unwillingness to 'wait and see,' we've assembled a roster with which we plan to advance through the Valve rankings," nafany wrote.

nafany and Ax1Le were on the lookout for a new team to join after being benched by AMKAL and BetBoom, respectively. On December 28, AMKAL announced they were shutting down after two years of operations.


Earlier this month, Ax1Le stood in for Kirill "⁠Boombl4⁠" Mikhailov at META Cup Season 3 in Almaty, averaging a 1.08 rating as BetBoom finished in first place in the $5,000 tournament.

The news marks groove's return to coaching after a year-long hiatus. He was released by Cloud9 in February 2025, when the North American organization withdrew from Counter-Strike. Months earlier, it had parted ways with four of its players, including Ax1Le, with Ilya "⁠Perfecto⁠" Zalutskiy released in April.

Rounding out TDK's roster are Aleksandr "⁠zorte⁠" Zagodyrenko, who, like Ax1Le, was benched by BetBoom in November, as well as Kirill "⁠Xant3r⁠" Kononov and Amin "⁠sugaR⁠" Azimov, formerly of Nemiga and Insilio, respectively.

"We're all contracted to different organizations, which have given their approval for this initiative—and we're extremely grateful for that," nafany added. """,


"""Qikert leaves MIBR: "I know I'm capable of more, and I'm ready to prove it"

The IEM Rio Major winner says he is open to offers as an IGL.

Aleksei "⁠Qikert⁠" Golubev has confirmed that he will be returning to PARIVISION's inactive roster following a three-month loan stint with MIBR.

The 26-year-old joined MIBR in September for the final stretch of the season amid an international transition for the team, which also welcomed AWPer Klimentii "⁠kl1m⁠" Krivosheev from G2's academy.

Qikert averaged a 0.94 rating during his loan stint, which culminated in a last-placed finish from the Budapest Major's Stage 2 following losses to Imperial, Passion UA and Liquid. It was the third event in a row that Qikert finished with a rating lower than 0.75 after previously struggling at the CS Asia Championships and PGL Masters Bucharest.


In a post on X, Qikert urged the community not to judge him "based on this strange season."

"There were many circumstances that prevented any of the MIBR players from showing their true level," he wrote. "I drew the right conclusions, and I will break through this.

"Judge me and my future team by results. Playbook, structure, protocols, reactions, vision and everything needed to build a strong team is ready."

Qikert added that, upon reflection, he concluded he wants to captain a team again after previously calling for Into the Breach and PARIVISION. He also opened the door to international teams, noting that he holds Schengen and US visas.

"I know I'm capable of more, and I'm ready to prove it," he wrote.

"My goal remains unchanged — to return to Tier-1 tournaments and compete at the highest level." """,


"""zweih joins PARIVISION in place of AW

Spirit's anchor in the second half of 2025 has found a new home going into the 2026 season.


PARIVISION has announced the signing of Ivan "⁠zweih⁠" Gogin, who joins on a transfer from Spirit after it was announced that the 18-year-old was being benched alongside Leonid "⁠chopper⁠" Vishnyakov to make way for Myroslav "⁠zont1x⁠" Plakhotia's return to the now Boris "⁠magixx⁠" Vorobiev-led team.

To make room for the newcomer, PARIVISION have parted ways with Andrey "⁠AW⁠" Anisimov, one of four youngsters in the team around AWPing in-game leader Dzhami "⁠Jame⁠" Ali. PARIVISION rose to prominence throughout 2025 with their young roster, culminating in a run to the third stage of the StarLadder Major in Budapest.

zweih was only in Spirit for five months after a summer transfer from Nemiga, but he lifted trophies at IEM Cologne and BLAST Bounty Season 2 Finals during that time. He struggled throughout the season posting only a 0.92 rating, however, and received criticism for not being ready to perform consistently at the highest level.

Still only 18-years-old, zweih will have a chance to continue his development under veterans Jame and Dastan "⁠dastan⁠" Akbayev in his new team after former coach Sergey "⁠hally⁠" Shavaev said that he "still needs to mature and become a more complete player to compete at the elite level." """,


"""Sources: 100 Thieves close in on poiii
The North American organization has set its sights on one of Sweden's most exciting prospects.

100 Thieves are close to securing the services of Alliance star Alex "⁠poiii⁠" Nyholm Sundgren, multiple sources have confirmed to HLTV and Fragbite. The 19-year-old is expected to become the third player to join the North American organization, which has already unveiled Håvard "⁠rain⁠" Nygaard and is on the brink of completing the signing of Nicolai "⁠device⁠" Reedtz.

poiii has established himself as one of Sweden's hottest prospects since joining EYEBALLERS in July 2024, with Jesper "⁠JW⁠" Wecksell labeling him the country's "next superstar." He has twice featured in HLTV's prospect report, the latest of which was at No.40 — a five-place jump from his previous appearance.

Last month, the 19-year-old averaged a 1.75 rating as Alliance beat Metizport 3-0 in the grand final of Svenska Cupen 2025, held in Stockholm.


100 Thieves' interest in poiii suggests a change in their planning. For a while, the North American organization was expected to secure a ready-made core to begin the new season with a VRS rank and some tournament invites. It even had talks with GamerLegion before the Major, presumably about the possibility of signing the core of the German organization's team.

Several sources have told HLTV that 100 Thieves are expected to pluck players from different teams and climb their way up the rankings — the same strategy deployed by Ninjas in Pyjamas at the end of 2024, when they changed all but one player, Artem "⁠r1nkle⁠" Moroz.

On Friday, 100 Thieves formally announced Lukas "⁠gla1ve⁠" Rossander as the team's head coach, with the four-time Major champion joining IGL rain as the first two pieces of the puzzle.

100 Thieves were not immediately available for comment. """,


"""BC.Game bench CacaNito
The team has made its third change of the off-season.


BC.Game have announced the benching of Aleksandar "⁠CacaNito⁠" Kjulukoski, leaving the organization with just three players on the active roster following the departures of Nemanja "⁠nexa⁠" Isaković and Luka "⁠emi⁠" Vuković.

It is the second time the Macedonian rifler has been moved to the team's reserves after he was benched alongside Jonas "⁠Lekr0⁠" Olofsson in February to make way for Cai "⁠CYPHER⁠" Watson and nexa.

He returned to the roster in May ahead of IEM Dallas to replace Joakim "⁠jkaem⁠" Myrbostad after the Norwegian was embroiled in several scandals and accused of owing over $300,000 in gambling debt.


Read more
BC.Game bench jkaem following accusations of him owing $300,000 in gambling debt
CacaNito first joined BC.Game in June 2024 and was the longest-serving member of the roster despite his time on the bench.

He averaged a 1.00 rating over 228 maps, during which the team competed almost exclusively in online competitions and made just two LAN appearances on HLTV at IEM Dallas and Red Bull GIBAWAY JOURNEY, and notably won ESL Challenge League Season 50 Europe Cup 2 shortly after Oleksandr "⁠s1mple⁠" Kostyliev's surprise addition.

His benching leaves the team with the following lineup: """,

"""w0nderful on beating FURIA: "We were preparing for this game for four days, so of course I was expecting this"

w0nderful believes the magic of the Major and NAVI's belief in themselves is helping them progress in Budapest.


Natus Vincere have caused a stir with their run at StarLadder Budapest Major, dispelling their patchy form of earlier in the season to make it all the way to the semi-finals, making a statement by knocking out FURIA in the process.

"In the quarter-final of a Major, everything can change," Ihor "⁠w0nderful⁠" Zhdanov told HLTV after securing a semi-final berth with said win over FURIA. "It's just the magic of the Major. You need to always believe in yourself and this believing will help you."

With a semi-final matchup against FaZe on the horizon, w0nderful chatted with HLTV about his team's memorable win over FURIA, his own improved form, and the looming spectre of FaZe.

How are you feeling?

I am feeling wonderful (smiles).

Were you expecting NAVI to have such a good performance in that match?

Yeah of course. We were preparing for this game for like four days, so of course I was expecting this.

I wanted to talk about your Major performance, because you've had one of the best tournaments of the season for you. B1ad3 was telling us a lot about how you've been working with your sports psychologist and how the bootcamp didn't go very well. What was your preparation for the Major like?

Just like usual, but I played my worst bootcamp ever I think (laughs). I just felt confidence, I just have it back kinda, because this year it was kind of tough for me, but now I'm feeling amazing.

This year it was kind of tough for me, but now I'm feeling amazing
Ihor "⁠w0nderful⁠" Zhdanov
Why do you think you're feeling amazing now, what's changed?

My mentality.

What did you do to change your mentality?

It's a secret.

Now that you've had such a good performance, do you have the confidence that you can keep this up, keep playing this well?

Yeah of course. I want to, step by step, go to our goals, so yeah.

It's just the magic of the Major. You need to always believe in yourself and this believing will help you
Ihor "⁠w0nderful⁠" Zhdanov
What do you think changed from the first FURIA game, because you played them earlier in the tournament and they smashed you? Why do you think you were able to turn it around?

First of all it was only best-of-one, and we just played really bad on Nuke. Best-of-three, especially in the quarter-final of a Major, everything can change. FaZe is showing a very good game, so it's just the magic of the Major. You need to always believe in yourself and this believing will help you.

Do you think you have an advantage in that sense, because you won the Copenhagen Major? You know that you can do it in these types of games.

Yeah. You just need confidence.

You have a matchup with FaZe coming up, how do you feel about that game?

It will be an amazing game, I know it already. """,

"""Snax returns to GamerLegion
The Pole is back for a second stint in the organization.


GamerLegion have announced the return of Janusz "⁠Snax⁠" Pogorzelski, with the Polish IGL set to take the place of the recently benched Erik "⁠ztr⁠" Gustafsson.

The announcement follows a busy period for GamerLegion, who also lost coach Ashley "⁠ash⁠" Battye due to burnout and had their core linked with a potential move to 100 Thieves.

This will be Snax's second stint in the organization after the Pole led the team for just under a year during 2023-2024 and notably helped them qualify for the PGL Major Copenhagen before departing for G2.

At the time, GamerLegion replaced him with ztr, with the organization now reversing the decision by snapping up the out-of-contract IGL.

The Pole will aim to stabilize a team whose form has deteriorated in recent months, slipping from the VRS top 10 to 25th after a run of disappointing performances, including a 1–3 exit at the Budapest Major Stage 1. """,

"""degster announces free agency
The Russian sniper is on the market after eight months on Falcons' bench.


Abdul "⁠degster⁠" Gasanov has announced his free agency following the termination of his contract with Falcons, bringing to an end the AWPer's year-long stint with the Saudi organization.

"I can confidently say that I have a tireless desire to work to achieve success with a new team and organization," degster said in a statement on X.

degster initially signed for Falcons in January of this year alongside Damjan "⁠kyxsan⁠" Stoilkovski and René "⁠TeSeS⁠" Madsen, joining as part of the former HEROIC core that would bring with them their VRS points.

The Russian sniper struggled to consistently hit top form whilst wearing a Falcons jersey, averaging a 1.02 rating during his tenure, but he did enjoy a memorable peak, earning the MVP award during a run to his first-ever significant trophy at PGL Bucharest.

Falcons were set to bring Ilya "⁠m0NESY⁠" Osipov onboard in a blockbuster signing soon after said PGL Bucharest run, thus degster was relegated to the bench to make room for the incoming superstar.

Since his benching degster has a single HLTV-recorded official in the books, playing alongside Timur "⁠FL4MUS⁠" Marev and Andrey "⁠Jerry⁠" Mekhryakov in mix-team MAJOR WINNERS in July. They lost their only game in the ESL Pro League Season 22 open qualifier. """

]

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 74.6 MB/s eta 0:00:00
# ...

# %%
# Загрузка нужных библиотек
import string
import re
import nltk
import spacy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt_tab')

# Загрузка моделей spaCy
nlp_en = spacy.load("en_core_web_sm")

# Загрузка стоп-слов
nltk.download('stopwords')
russian_stopwords = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Предобработка текста
def normalize_text(text):
    new_text = []
    for sentence in text:
        sentence = sentence.lower()
        sentence = re.sub(r'[^\w\s]', ' ', sentence)
        # Нужно убрать числа так как они часто попадались в BOW
        sentence = re.sub(r'[0-9]+', ' ', sentence)
        tokens = sentence.split()
        filtered_tokens = [token for token in tokens if token not in russian_stopwords]
        sentence = ' '.join(filtered_tokens)

        # Лемматизация
        doc = nlp_en(sentence)
        lemmas = [token.lemma_ for token in doc if token.is_alpha]
        sentence = ' '.join(lemmas)
        new_text.append(sentence)

    return new_text

documents = normalize_text(text_documents)

print("Предобработанные документы:")
for i, doc in enumerate(documents, 1):
    print(f"Документ {i}: {doc}")





# # Лемматизация английского текста
# english_lemmas_spacy = lemmatize_with_spacy(documents[0], nlp_en)
# print(english_lemmas_spacy)
# Out:
# Предобработанные документы:
# Документ 1: kyousuke miss bounty final due visa issue nucleonz get call academy team join falcon malta falcon announce maxim kyousuke lukin miss blast bounty final malta due unresolved visa complication rest team tackle first lan january russian rifler finish second run rookie year land shy placement top player rank post rating throughout four map falcon play online ecstatic monte help team qualify lan final falcon call upon matej nucleonz trajkoski academy roster fill kyousuke absence make blast bounty first event top tier opposition record first map hltv red bull gibaway journey november year old part falcon force since academy roster announce september post rating aforementione event sweden joint high alongside vladimir veno stankovic falcon force group stage finish
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer  # Для создания Bag of Words

# %%
# Создание векторизатора
count_vectorizer = CountVectorizer()

# Обучение векторизатора и преобразование документов
bow_matrix = count_vectorizer.fit_transform(documents)

# Получение списка фичей (слов)
feature_names = count_vectorizer.get_feature_names_out()

# Преобразование разреженной матрицы в плотную для наглядности
bow_df = pd.DataFrame(
    bow_matrix.toarray(),
    columns=feature_names,
    index=[f'Документ {i+1}' for i in range(len(documents))]
)

# Вывод матрицы Bag of Words
print("Матрица Bag of Words:")
print(bow_df)
# Out:
# Матрица Bag of Words:
#              abdul  able  absence  academy  accompany  accusation  accuse  \
# Документ 1       0     0        1        3          0           0       0
# Документ 2       0     0        0        0          1           0       0
# Документ 3       0     0        0        0          0           0       0
# Документ 4       0     0        0        1          0           0       0
# Документ 5       0     0        0        0          0           0       0
# Документ 6       0     0        0        0          0           0       0
# Документ 7       0     0        0        0          0           1       1
# Документ 8       0     1        0        0          0           0       0
# Документ 9       0     0        0        0          0           0       0
# Документ 10      1     0        0        0          0           0       0
#
#              achieve  active  ad  ...  yes  young  youngster  zagodyrenko  \
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer # Для создания TF-IDF

# %%
# Создание TF-IDF векторизатора
tfidf_vectorizer = TfidfVectorizer()

# Обучение векторизатора и преобразование документов
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)

# Преобразование в DataFrame
tfidf_df = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=tfidf_vectorizer.get_feature_names_out(),
    index=[f'Документ {i+1}' for i in range(len(documents))]
)

# Вывод матрицы TF-IDF
print("Матрица TF-IDF:")
print(tfidf_df)
# Out:
# Матрица TF-IDF:
#                 abdul      able   absence   academy  accompany  accusation  \
# Документ 1   0.000000  0.000000  0.087908  0.224190   0.000000    0.000000
# Документ 2   0.000000  0.000000  0.000000  0.000000   0.039769    0.000000
# Документ 3   0.000000  0.000000  0.000000  0.000000   0.000000    0.000000
# Документ 4   0.000000  0.000000  0.000000  0.062827   0.000000    0.000000
# Документ 5   0.000000  0.000000  0.000000  0.000000   0.000000    0.000000
# Документ 6   0.000000  0.000000  0.000000  0.000000   0.000000    0.000000
# Документ 7   0.000000  0.000000  0.000000  0.000000   0.000000    0.083137
# Документ 8   0.000000  0.044018  0.000000  0.000000   0.000000    0.000000
# Документ 9   0.000000  0.000000  0.000000  0.000000   0.000000    0.000000
# Документ 10  0.078978  0.000000  0.000000  0.000000   0.000000    0.000000
#
#                accuse   achieve    active        ad  ...       yes     young  \
# ...

# %%
bow_sum = np.sum(bow_matrix.toarray(), axis=0)


word_bow_dict = dict(zip(feature_names, bow_sum))

top_bow_words = sorted(word_bow_dict.items(), key=lambda x: x[1], reverse=True)[:10]

print("=== Топ-10 слов по всей коллекции ===\n")
print("Топ-10 слов по BOW (самые частые в коллекции):")
for word, count in top_bow_words:
    print(f"- {word}: {count} раз")

tfidf_sum = np.sum(tfidf_matrix.toarray(), axis=0)

word_tfidf_dict = dict(zip(feature_names, tfidf_sum))

top_tfidf_words = sorted(word_tfidf_dict.items(), key=lambda x: x[1], reverse=True)[:10]

print("\nТоп-10 слов по TF-IDF (с наибольшим весом по всей коллекции):")
for word, score in top_tfidf_words:
    print(f"- {word}: {score:.4f}")

print("\nСравнение топ-10 слов:")
bow_words = [word for word, _ in top_bow_words]
tfidf_words = [word for word, _ in top_tfidf_words]

common_words = set(bow_words) & set(tfidf_words)
bow_only = set(bow_words) - common_words
tfidf_only = set(tfidf_words) - common_words

if common_words:
    print(f"Общие слова в обоих топ-10: {', '.join(common_words)}")
if bow_only:
    print(f"Только в BOW топ-10: {', '.join(bow_only)}")
if tfidf_only:
    print(f"Только в TF-IDF топ-10: {', '.join(tfidf_only)}")
# Out:
# === Топ-10 слов по всей коллекции ===
#
# Топ-10 слов по BOW (самые частые в коллекции):
# - team: 39 раз
# - major: 21 раз
# - falcon: 19 раз
# - year: 18 раз
# - season: 17 раз
# - make: 16 раз
# - organization: 15 раз
# - player: 14 раз
# - bench: 13 раз
# - game: 13 раз
#
# Топ-10 слов по TF-IDF (с наибольшим весом по всей коллекции):
# - team: 0.9553
# - falcon: 0.9226
# - bench: 0.6144
# - major: 0.5983
# - organization: 0.5848
# - game: 0.5333
# - year: 0.4873
# - make: 0.4817
# - season: 0.4773
# - degster: 0.4739
#
# Сравнение топ-10 слов:
# Общие слова в обоих топ-10: make, season, year, team, falcon, major, organization, bench, game
# Только в BOW топ-10: player
# Только в TF-IDF топ-10: degster

# %%
# Функция для предобработки текста
def preprocess_text(text):
    """Функция для базовой обработки текста"""
    # Преобразуем в нижний регистр
    text = text.lower()

    # Удаляем пунктуацию (оставляем только буквы и пробелы)
    text = re.sub(r'[^\w\s]', '', text)

    # Токенизация (разбиение на слова)
    tokens = word_tokenize(text)

    return tokens

# Предобрабатываем каждое предложение в корпусе
processed_corpus = [preprocess_text(sentence) for sentence in documents]

# %%
model = Word2Vec(
    sentences=processed_corpus,  # Наш корпус предложений
    vector_size=100,  # Размерность векторов (обычно от 100 до 300)
    window=5,  # Размер контекстного окна (сколько слов слева и справа учитывать)
    min_count=1,  # Минимальная частота слова для включения в модель (здесь 1, т.к. у нас маленький корпус)
    sg=1,  # 1 = Skip-gram, 0 = CBOW
    hs=0,  # 0 = использовать negative sampling, 1 = иерархический softmax
    negative=5,  # Количество "негативных" семплов для negative sampling
    ns_exponent=0.75,  # Экспонента для отрицательного сэмплирования
    cbow_mean=1,  # Для CBOW: 1 = использовать среднее, 0 = сумму
    alpha=0.025,  # Начальная скорость обучения
    min_alpha=0.0001,  # Минимальная скорость обучения
    seed=42,  # Для воспроизводимости результатов
    workers=4,  # Количество потоков для параллельного обучения
)

# %%
def sentence_to_vector(sentence, model):
    """
    Преобразует предложение в вектор, усредняя векторы слов

    Args:
        sentence: Исходное предложение
        model: Word2Vec

    Returns:
        Вектор предложения
    """
    # Предобрабатываем предложение
    words = preprocess_text(sentence)

    # Отбираем только слова, которые есть в модели
    words = [word for word in words if word in model.wv]

    if not words:
        # Если не нашлось ни одного известного слова, вернем нулевой вектор
        return np.zeros(model.vector_size)

    # Получаем векторы слов
    word_vectors = [model.wv[word] for word in words]

    # Возвращаем средний вектор
    return np.mean(word_vectors, axis=0)

# Создаем векторные представления для всех предложений корпуса
sentence_vectors = [sentence_to_vector(sentence, model) for sentence in documents]

def find_similar_sentences(query, corpus, model, top_n=10):
    """
    Находит предложения, наиболее похожие на запрос

    Args:
        query: Запрос (строка)
        corpus: Список предложений для поиска
        model: Модель Word2Vec
        top_n: Количество результатов для вывода

    Returns:
        Список кортежей (предложение, оценка сходства)
    """
    # Преобразуем запрос в вектор
    query_vector = sentence_to_vector(query, model)
    query_norm = np.linalg.norm(query_vector)
    if query_norm == 0:
    # В запросе не оказалось слов из словаря модели
        return []

    similarities = []
    for i, sentence_vector in enumerate(sentence_vectors):
        denom = query_norm * np.linalg.norm(sentence_vector)
        if denom == 0:
            similarity = 0.0
        else:
            similarity = float(np.dot(query_vector, sentence_vector) / denom)

        similarities.append((documents[i], similarity))

    # Сортируем по убыванию сходства
    similarities.sort(key=lambda x: x[1], reverse=True)

    # Возвращаем top_n результатов
    return similarities[:top_n]

print("\n=== Поиск похожих предложений ===")
for query in text_documents:
    # Чтобы запрос не был слишком громозким
    tokens = query.split()
    query = " ".join(tokens)
    print(f"\nЗапрос: {query}")
    similar = find_similar_sentences(query, documents, model)
    for i, (sentence, score) in enumerate(similar, 1):
        print(f"{i}. {sentence[:20]} (сходство: {score:.4f})")
# Out:
# === Поиск похожих предложений ===
#
# ...

# %%
docs_clean = [" ".join(preprocess_text(d)) for d in documents]
labels = [f"Док {i+1}" for i in range(len(docs_clean))]

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

bow = CountVectorizer()
X_bow = bow.fit_transform(docs_clean)

tfidf = TfidfVectorizer()
X_tfidf = tfidf.fit_transform(docs_clean)

# %%
from sklearn.manifold import MDS
from sklearn.metrics.pairwise import cosine_distances

def plot_mds(X, labels, title):
    D = cosine_distances(X)
    coords = MDS(n_components=2, dissimilarity="precomputed", random_state=42).fit_transform(D)

    plt.figure(figsize=(7,6))
    plt.scatter(coords[:,0], coords[:,1])
    for i, lab in enumerate(labels):
        plt.text(coords[i,0], coords[i,1], " " + lab, va="center")
    plt.title(title)
    plt.tight_layout()
    plt.show()

plot_mds(X_bow, labels, "BoW косинусное расстояние")
plot_mds(X_tfidf, labels, "TF-IDF косинусное расстояние")

# %% [markdown]
# **Задание 2: Морфологическая разметка текста**

# %% [markdown]
# 1. Возьмите отрывок текста (минимум 300 слов) на русском и английском языке.
# 2. Для русского языка используйте PyMorphy2 или PyMorphy3, для английского - NLTK или SpaCy для проведения морфологического анализа.
# 3. Выполните следующие операции:
# * Определите части речи для каждого слова в тексте
# * Для существительных определите падеж, род и число
# * Для глаголов определите время, лицо и число
# * Создайте частотный словарь частей речи в тексте
# 4. Разработайте функцию, которая будет автоматически изменять текст, заменяя все существительные на их форму множественного числа (где возможно).
# 5. Результаты морфологического анализа должны быть представлены в виде таблицы.
# 6. Оцените и прокомментируйте точность определения морфологических характеристик
#
# **Ответ:** морфологические характеристики NLTK и Pymorphy3 определили довольно точно (В Pymorphy3 всего 2 UKNOWN см. таблицу). С NLTK трудность заключалось в том, как убрать пунктуацию, но хорошо когда есть теги, которые сразу показывают всю информацию о слове (вид, число, падеж). В Pymorphy3 конечно есть больше свободы, то есть, можно выбрать 1) что именно показывать 2) и для каких слов

# %%
# 6. **Ответ:** морфологические характеристики NLTK и Pymorphy3 определили довольно точно (В Pymorphy3 всего 2 UKNOWN см. таблицу). С NLTK трудность заключалось в том, как убрать пунктуацию, но хорошо когда есть теги, которые сразу показывают всю информацию о слове (вид, число, падеж). В Pymorphy3 конечно есть больше свободы, то есть, можно выбрать 1) что именно показывать 2) и для каких слов

# %%
# ваш код
english_text = """Latin America and the Catholic Church
The Catholic Church has had a great influence on people in Latin America as people there have always been very religious. However, people’s attitude towards Rome as well as the Pope changed in the 1980s in Nicaragua. Socioeconomic situation in the country became intolerable for thousands of people who had to polarized society where rich people were supported by the Catholic Church in Rome while some Catholic priests started supporting people’s struggle against the social oppression and even helped Marxist (Berntzen, 2012). Hundreds of people had been killed on both sides and everybody was waiting for peace and justice. The visit of John Paul II was seen as a possible way to console people but everybody’s hope vanished during the mass held in the central square of Managua.

It is necessary to look back and shed more light on the position of the Catholic Church and John Paul II. The Pope was Polish and he learnt about Communist and Marxist approaches from his own sad experiences so he was strongly against any demonstration of this social paradigm (Moss, 2008). This fact can explain the Pope’s strict position and unwillingness to show any support to a liberation-theology proponents (Kraul & Chu, 2005).

Nonetheless, people of Nicaragua did not think of political paradigm, they wanted peace and consolation which could be given by a few words about the victims of the oppressive regime in the Pope’s mass (Riding, 1983). However, John Paul II did not “give even a crumb to the revolution” as he did not want to listen about it (Hoyt, 1996). People were upset and devastated.

Lots of people of Nicaragua were afraid of more killings and persecution. They were afraid that such position of the Pope will make the Government even more oppressive. In reality, this is exactly what happened. The position of the Roman Catholic Church and its Head made the society of Nicaragua even more polarized and the tension started increasing steadily.

The rich obtained support of one of the most powerful institutions in the country and exploited this in their attempts to suppress people’s resistance. The Roman Church managed to retain its hierarchy and avoid the split into a popular church and the conventional one. Of course, the price of this success was very high and it cost the country hundreds of people’s lives. People still remember about their hopes and the way they were destroyed."""

russian_text = """Мужчина постанывал, перекатываясь с боку на бок в поисках диванной ложбинки. В ней он чувствовал себя умиротворенно и был похож на младенца с мясистой головой и диатезными щеками.

Зуб мудрости лез. Тужился, продавливал дорогу через опухшую десну в пасть Соловейчика.

- Скушай курочку, - жена подняла куриную ножку, от которой отделялись волокна мяса, - Мягенькое.

Соловейчик переместил тело к журнальному столику, где обнаружил пол литры, рюмки и ужин:

- Придётся поесть, - жалобно пробубнил, скрыв ухмылку.

 Действительно, курица отменная. Томлённая в апельсиновом соке, с черносливом и тыквой. От выпитого зуб угомонился и Соловейчик попробовал им жевать, - осторожно, вдумчиво. Вдруг ему привиделась деревня, свет, стекающий в щели курятника, шорохи,  кудахтанье соседок. Он почувствовал, как его зад раздувает и оттуда выталкивается яйцо.

Удивившись ощущениям, отложил ножку. Налил, глотнул, предварительно погоняв водку по дёснам:

- Не поверишь, что померещилось - курицей был! Вот этой вот самой, - он потряс костью, - Давился кукурузой, выдавливал яйца...Жуть.

- Обезболивающее не надо с водкой мешать.

- Глянь, что там с зубом? - Соловейчик поморщился, - Вроде онемело.

 Жена вытерла  пальцы о карманы халата, чтобы не залапать жиром куперозные щёки мужа, заглянула в темноту:

- Не вижу ничего. Так чувствуешь? -  провела пальцем по десне, и Соловейчик словно оказался с изнанки чужой души: «Ждала, когда за неё начнут жить. Из-за мягкотелости,  душевной лени ни к чему не стремилась. Терпела, соглашалась и всему уступала. Сдалась мерности и скучности существования. Теперь боится обнаружить, что могло быть по-другому, что всё надуманное и не настоящее, а за пределами уютной непримечательности и серости есть любопытное и удивительное».

Соловейчик отодвинулся. Жена смотрела на него с жалостью и сопереживанием. Это только дежурный вид, который от неё ожидают.  Эмоциональная мимикрия. Попытка трухлявого нутра выглядеть живым и человечным.

Теперь Соловейчик понимал.

Следуя догадке, он приложил палец к пробивающемуся зубу. Да, вот и его тёмный подвал: «Девочка готова была расплакаться, а он всё вбивал ей в голову нравоучения. Приятно было осознавать важность, правильность и наслаждаться добродетелью. Он журил её за затасканное бельё, неопрятность, вялую грудь, затем описал во что сифилис превратит её милое личико. Гладя по голове, рассказывал, что ребенок у такой точно будет уродцем. Стыдил матерью, опозоренной дочерью-шалавой. А когда проститутка разрыдалась, не выдержав потока отборной морали, выебал её сзади, без тени зазрения, щипая до появления синяков худые бёдра».

-      Плоскогубцы где?!  - Соловейчик спружинил с дивана к инструментам, - Нахер мне такой зуб, сука, мудрости?

Через некоторое время, смотря в без толку забрызганное кровью зеркало, Соловейчик пытался разглядеть в отражении тени, блуждающие в его сознании. Видно ли их другим?"""

# %%
# !pip install nltk spacy pymorphy3
# !pip install inflect

from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
from nltk.tokenize.treebank import TreebankWordDetokenizer
import nltk
import string
import pymorphy3
import inflect

nltk.download('universal_tagset')
nltk.download('averaged_perceptron_tagger_eng')

import spacy
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 34.8 MB/s eta 0:00:00
# ...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.

# %%
# Распределить на части речи ENG
text_tok = word_tokenize(english_text)
tagged = nltk.pos_tag(text_tok)
list_of_tagged = []

for elem in tagged:
    tag_tog = '_'.join(elem)
    list_of_tagged.append(tag_tog)

# Тут также определено число существительных (род, число, лицо у глаголов), так как в NLTK автоматически
# NN, NNP - единственное число, NNS, NNPS - множественное число
# VBZ - 3 лицо, ед. ч., настоящее время, VBN - прошедшее время и тд.
print(list_of_tagged)
# Out:
# ['Latin_NNP', 'America_NNP', 'and_CC', 'the_DT', 'Catholic_NNP', 'Church_NNP', 'The_DT', 'Catholic_NNP', 'Church_NNP', 'has_VBZ', 'had_VBD', 'a_DT', 'great_JJ', 'influence_NN', 'on_IN', 'people_NNS', 'in_IN', 'Latin_NNP', 'America_NNP', 'as_IN', 'people_NNS', 'there_RB', 'have_VBP', 'always_RB', 'been_VBN', 'very_RB', 'religious_JJ', '._.', 'However_RB', ',_,', 'people_NNS', '’_VBP', 's_JJ', 'attitude_NN', 'towards_NNS', 'Rome_NNP', 'as_RB', 'well_RB', 'as_IN', 'the_DT', 'Pope_NNP', 'changed_VBD', 'in_IN', 'the_DT', '1980s_CD', 'in_IN', 'Nicaragua_NNP', '._.', 'Socioeconomic_NNP', 'situation_NN', 'in_IN', 'the_DT', 'country_NN', 'became_VBD', 'intolerable_JJ', 'for_IN', 'thousands_NNS', 'of_IN', 'people_NNS', 'who_WP', 'had_VBD', 'to_TO', 'polarized_VBN', 'society_NN', 'where_WRB', 'rich_JJ', 'people_NNS', 'were_VBD', 'supported_VBN', 'by_IN', 'the_DT', 'Catholic_NNP', 'Church_NNP', 'in_IN', 'Rome_NNP', 'while_IN', 'some_DT', 'Catholic_NNP', 'priests_NNS', 'started_VBD', 'supporting_
# ...

# %%
# Распределить на части речи RUS
morph = pymorphy3.MorphAnalyzer()
text_tok = word_tokenize(russian_text)
rus_list_of_tagged = []

for word in text_tok:
    parses = morph.parse(word)
    best_parse = parses[0]
    pos = best_parse.tag.POS
    _case = best_parse.tag.case
    gender = best_parse.tag.gender
    number = best_parse.tag.number
    person = best_parse.tag.person
    tense = best_parse.tag.tense
    if pos == 'NOUN':
        rus_list_of_tagged.append(f'{word}_{pos}_{_case}_{gender}_{number}')
    elif pos == 'VERB':
        rus_list_of_tagged.append(f'{word}_{pos}_{person}_{tense}_{number}')
    else:
        rus_list_of_tagged.append(f'{word}_{pos}')

print(rus_list_of_tagged)
# Out:
# ['Мужчина_NOUN_nomn_masc_sing', 'постанывал_VERB_None_past_sing', ',_None', 'перекатываясь_GRND', 'с_PREP', 'боку_NOUN_loc2_masc_sing', 'на_PREP', 'бок_NOUN_accs_masc_sing', 'в_PREP', 'поисках_NOUN_loct_masc_plur', 'диванной_ADJF', 'ложбинки_NOUN_gent_femn_sing', '._None', 'В_PREP', 'ней_NPRO', 'он_NPRO', 'чувствовал_VERB_None_past_sing', 'себя_NPRO', 'умиротворенно_ADVB', 'и_CONJ', 'был_VERB_None_past_sing', 'похож_ADJS', 'на_PREP', 'младенца_NOUN_gent_masc_sing', 'с_PREP', 'мясистой_ADJF', 'головой_NOUN_ablt_femn_sing', 'и_CONJ', 'диатезными_ADJF', 'щеками_NOUN_ablt_femn_plur', '._None', 'Зуб_NOUN_nomn_masc_sing', 'мудрости_NOUN_gent_femn_sing', 'лез_VERB_None_past_sing', '._None', 'Тужился_VERB_None_past_sing', ',_None', 'продавливал_VERB_None_past_sing', 'дорогу_NOUN_accs_femn_sing', 'через_PREP', 'опухшую_PRTF', 'десну_NOUN_accs_femn_sing', 'в_PREP', 'пасть_INFN', 'Соловейчика_NOUN_gent_masc_sing', '._None', '-_None', 'Скушай_VERB_None_None_sing', 'курочку_NOUN_accs_femn_sing', 
# ...

# %%
# Словарь частей речи ENG
tokens = word_tokenize(english_text)
tokens = [t for t in tokens if re.search(r"[A-Za-z0-9]", t)]
tagged = pos_tag(tokens)
pos_counts = Counter(tag for _, tag in tagged)

print(pos_counts.most_common())
# Out:
# [('NNP', 54), ('IN', 52), ('DT', 48), ('NN', 46), ('JJ', 31), ('VBD', 30), ('NNS', 27), ('RB', 21), ('CC', 20), ('VB', 14), ('VBN', 11), ('TO', 9), ('PRP', 9), ('CD', 8), ('VBZ', 6), ('VBP', 5), ('PRP$', 5), ('VBG', 4), ('MD', 3), ('WP', 2), ('JJR', 2), ('RBR', 2), ('WRB', 1), ('WDT', 1), ('RBS', 1)]

# %%
# Словарь частей речи RUS
pos_counts = Counter()

for word in text_tok:

    if all(not ch.isalnum() and ch not in "ёЁ" for ch in word):
        continue
    parse = morph.parse(word)[0]
    pos = parse.tag.POS or "UNKN"
    pos_counts[pos] += 1

print(pos_counts.most_common())
# Out:
# [('NOUN', 127), ('VERB', 62), ('PREP', 43), ('ADJF', 39), ('CONJ', 33), ('NPRO', 20), ('ADVB', 20), ('PRCL', 16), ('INFN', 14), ('PRTF', 10), ('GRND', 9), ('ADJS', 3), ('PRED', 1)]

# %%
#  Функция которая меняет ед. сущ. на мн. сущ. ENG
p = inflect.engine()
nlp = spacy.load("en_core_web_sm")

def pluralize_nouns_spacy(text: str) -> str:
    doc = nlp(text)
    out = []

    for tok in doc:
        # NN/NNP = обычно единственное число (NNS/NNPS = уже множественное)
        if tok.tag_ in ("NN", "NNP"):
            pl = p.plural_noun(tok.text) or p.plural(tok.text)

            # сохранение регистра
            if tok.text.isupper():
                pl = pl.upper()
            elif tok.text.istitle():
                pl = pl.title()

            out.append(pl + tok.whitespace_)
        else:
            out.append(tok.text_with_ws)

    return "".join(out)

print(pluralize_nouns_spacy(english_text))
# Out:
# Latins Americas and the Catholics Churches
# The Catholics Churches has had a great influences on people in Latins Americas as people there have always been very religious. However, people’s attitudes towards Romes as well as the Popes changed in the 1980s in Nicaraguas. Socioeconomic situations in the countries became intolerable for thousands of people who had to polarized societies where rich people were supported by the Catholics Churches in Romes while some Catholic priests started supporting people’s struggles against the social oppressions and even helped Marxists (Berntzens, 2012). Hundreds of people had been killed on both sides and everybodies was waiting for peaces and justices. The visits of Johns Pauls IIS was seen as a possible ways to console people but everybodies’s hopes vanished during the masses held in the central squares of Managuas.
#
# ...

# %%
#  Функция которая меняет ед. сущ. на мн. сущ. RUS
detok = TreebankWordDetokenizer()
def pluralize_nouns_pymorphy() -> str:

    tokens = word_tokenize(russian_text)
    new_tokens = []

    for w in tokens:
        if any(ch.isalpha() for ch in w):
            p = morph.parse(w)[0]
            if p.tag.POS == "NOUN" and p.tag.number == "sing":
                gramm = {"plur"}
                if p.tag.case:
                    gramm.add(p.tag.case)
                if p.tag.animacy:
                    gramm.add(p.tag.animacy)

                inf = p.inflect(gramm)
                if inf:
                    w = inf.word
        new_tokens.append(w)
    return new_tokens

new_text = detok.detokenize(pluralize_nouns_pymorphy())
print(new_text)
# Out:
# мужчины постанывал, перекатываясь с боках на бока в поисках диванной ложбинок . В ней он чувствовал себя умиротворенно и был похож на младенцев с мясистой головами и диатезными щеками . зубы мудростей лез . Тужился, продавливал дороги через опухшую дёсны в пасть соловейчиков . - Скушай курочек, - жёны подняла куриную ножки, от которой отделялись волокна мяса, - Мягенькое . соловейчики переместил тела к журнальному столикам, где обнаружил полы литры, рюмки и ужины: - Придётся поесть, - жалобно пробубнил, скрыв ухмылки . Действительно, курицы отменная . Томлённая в апельсиновом соках, с черносливами и тыквами . От выпитого зубы угомонился и соловейчики попробовал им жевать, - осторожно, вдумчиво . Вдруг ему привиделась деревни, свет, стекающий в щели курятников, шорохи, кудахтанья соседок . Он почувствовал, как его зады раздувает и оттуда выталкивается яйца . Удивившись ощущениям, отложил ножки . Налил, глотнул, предварительно погоняв водки по дёснам: - Не поверишь, что померещилось - 
# ...

# %%
# Таблица разметки ENG
eng_tokens = word_tokenize(english_text)
eng_tagged = nltk.pos_tag(eng_tokens)  # список (token, tag)

eng_df = pd.DataFrame(eng_tagged, columns=["token", "pos_tag"])


# Таблица разметки RUS
morph = pymorphy3.MorphAnalyzer()
rus_tokens = word_tokenize(russian_text)

rus_rows = []
for word in rus_tokens:
    if all(not ch.isalnum() and ch not in "ёЁ" for ch in word):
        continue

    p = morph.parse(word)[0]
    pos = p.tag.POS or "UNKN"

    row = {
        "token": word,
        "pos_tag": pos,
        "case": p.tag.case,
        "gender": p.tag.gender,
        "number": p.tag.number,
        "person": p.tag.person,
        "tense": p.tag.tense,
    }
    rus_rows.append(row)

rus_df = pd.DataFrame(rus_rows)



# 3) Таблицы частот POS
eng_tokens_np = [t for t in word_tokenize(english_text) if re.search(r"[A-Za-z0-9]", t)]
eng_pos_counts = Counter(tag for _, tag in pos_tag(eng_tokens_np))
eng_freq_df = pd.DataFrame(eng_pos_counts.most_common(), columns=["pos_tag", "count"])

rus_pos_counts = Counter()
for word in rus_tokens:
    if all(not ch.isalnum() and ch not in "ёЁ" for ch in word):
        continue
    pos = morph.parse(word)[0].tag.POS or "UNKN"
    rus_pos_counts[pos] += 1

rus_freq_df = pd.DataFrame(rus_pos_counts.most_common(), columns=["pos_tag", "count"])


# Таблицы
print("ENG tagged table:")
print(eng_df)

print("\nRUS tagged table:")
print(rus_df)

print("\nENG POS frequency:")
print(eng_freq_df)

print("\nRUS POS frequency:")
print(rus_freq_df)
# Out:
# ENG tagged table:
#          token pos_tag
# 0        Latin     NNP
# 1      America     NNP
# 2          and      CC
# 3          the      DT
# 4     Catholic     NNP
# ..         ...     ...
# 457        way      NN
# 458       they     PRP
# 459       were     VBD
# 460  destroyed     VBN
# 461          .       .
#
# [462 rows x 2 columns]
#
# RUS tagged table:
#              token pos_tag  case gender number person tense
# 0          Мужчина    NOUN  nomn   masc   sing   None  None
# 1       постанывал    VERB  None   masc   sing   None  past
# 2    перекатываясь    GRND  None   None   None   None  pres
# 3                с    PREP  None   None   None   None  None
# 4             боку    NOUN  loc2   masc   sing   None  None
# ..             ...     ...   ...    ...    ...    ...   ...
# 392       сознании    NOUN  loct   neut   sing   None  None
# 393          Видно    CONJ  None   None   None   None  None
# 394             ли    CONJ  None   None   None   None  None
# ...

# %% [markdown]
# **Задание 3: Синтаксический анализ предложений**

# %% [markdown]
# 1. Возьмите 2 простых и 3 сложных предложений на русском и английском языке (всего 10 предложений).
# 2. Используйте SpaCy для построения синтаксических деревьев этих предложений.
# 3. Для каждого предложения:
# * Визуализируйте синтаксическое дерево
# * Выделите все подлежащие и сказуемые
# * Найдите все пары слов, связанные отношением определения (прилагательное-существительное)
# 4. Разработайте функцию для извлечения всех объектных и субъектных отношений из предложения в формате (субъект, предикат, объект).
# 5. Объясните, какие трудности возникают при синтаксическом анализе сложных предложений
#
# Ответ: При синтаксическом анализе сложных предложений возникает множество трудностей. Стоит отметить, что инструмент spaCy хоть и является весьма хорошим и акутальным инструментов в наше время, не очень хорошо справляется с работой выделения подлежащего и сказуемого, а также других частей предложения. Конечно же проблема является в том, что в русском языке подлежащим может быть любая часть речи, а также у этого подлежащего может быть множетсво сказуемых. Из-за этого нужно добавлять множество правил, чтобы взять все подлежащие и сказуемые и даже в этом случае собрать их всех остается довольно затруднительным. В английском языке все также довольно не легко. Существуют те же проблемы, что и в русском, но также при попытке вывести отношения в формате (субъект, предикат, объект), учитывать также предлоги и артикли очень трудно без дополнительных функций или условий.

# %%
# !python -m spacy download ru_core_news_md
# !python -m spacy download en_core_web_md
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 MB 12.7 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 19.7 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# ваш код
english_sentences = [
    "He went outside.",
    "We bought expensive chocolate.",
    "The sun was setting, and the sky was painted with shades of orange and pink.",
    "My mom used to be a police officer when she was 25 years old.",
    "When I returned, everyone was already asleep."
]

russian_sentences = [
    "Он вышел на улицу.",
    "Мы купили шоколад.",
    "Мы хотели пирога, но яблоки еще не созрели.",
    "Мне было сложно понять, как ей удалось так быстро привыкнуть к новому городу.",
    "Я был рад, что всё хорошо закончилось."
]

# %%
# Загрузка языковых моделей
nlp_ru = spacy.load("ru_core_news_md")
nlp_en = spacy.load("en_core_web_md")

# %%
from spacy import displacy

# %%
# Визуализация дерева зависимостей для русского языка
for sentence in russian_sentences:
    doc_ru = nlp_ru(sentence)

    print(f"Sentence {russian_sentences.index(sentence)}")
    displacy.render(doc_ru, style="dep", jupyter=True, options={"distance": 100, "compact": True})
# Out:
# Sentence 0
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="e594ef352b52482b99db6014e4d41487-0" class="displacy" width="450" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Он</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">вышел</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
# ...

# %%
# Визуализация дерева зависимостей для английского языка
for sentence in english_sentences:
    doc_en = nlp_en(sentence)

    print(f"Sentence {english_sentences.index(sentence)}")
    displacy.render(doc_en, style="dep", jupyter=True, options={"distance": 100, "compact": True})
# Out:
# Sentence 0
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="38d9da726ca148488147fe02f4f9bc53-0" class="displacy" width="350" height="187.0" direction="ltr" style="max-width: none; height: 187.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="97.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">He</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="97.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">went</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="97.0">
# ...

# %%
def find_subj_and_pred_eng(doc):
    subj = []
    pred_tokens = []
    root = None

    # Находим корень
    for token in doc:
        if token.dep_ == "ROOT":
            root = token
            pred_tokens.append(token)
            break

    if not root:
        return [], []

    # Находим все компоненты составного сказуемого
    for token in doc:
        if token.dep_ in ["aux", "auxpass"] and token.head in [root] + [t for t in pred_tokens]:
            pred_tokens.append(token)

    # Составляем сказуемое в правильном порядке
    pred = [doc[i].text for i in sorted([t.i for t in pred_tokens])]

    # Ищем подлежащее где угодно в предложении
    for token in doc:
        if token.dep_ in ["nsubj", "nsubjpass"]:
            # Проверяем, является ли это подлежащим по отношению к ROOT или его компонентам
            current = token
            while current.head != current:  # Поднимаемся по дереву до корня
                if current.head in pred_tokens or current.head == root:
                    # Нашли подлежащее, связанное с нашим сказуемым
                    subj.append(token.text)
                    break
                current = current.head

    # Если все равно не нашли подлежащее - ищем более агрессивно
    if not subj:
        for token in doc:
            if token.dep_ in ["nsubj", "nsubj:pass"]:
                subj.append(token.text)

    return subj, pred

# %%
print("English sentences")
for text in english_sentences:
    doc = nlp_en(text)
    subject, predicate = find_subj_and_pred_eng(doc)
    print(f"Предложение: {text}")
    print(f"Подлежащее: {subject}, Сказуемое: {predicate}")
    print()
# Out:
# English sentences
# Предложение: He went outside.
# Подлежащее: ['He'], Сказуемое: ['went']
#
# Предложение: We bought expensive chocolate.
# Подлежащее: ['We'], Сказуемое: ['bought']
#
# Предложение: The sun was setting, and the sky was painted with shades of orange and pink.
# Подлежащее: ['sun', 'sky'], Сказуемое: ['was', 'setting']
#
# Предложение: My mom used to be a police officer when she was 25 years old.
# Подлежащее: ['mom', 'she'], Сказуемое: ['used']
#
# Предложение: When I returned, everyone was already asleep.
# Подлежащее: ['I', 'everyone'], Сказуемое: ['was']

# %%
def find_subj_pred_rus(doc):
    root = None
    pred_tokens = []

    for token in doc:
        if token.dep_ == "ROOT":
            root = token
            pred_tokens.append(token)
            break

    if not root:
        return [], []

    changed = True
    while changed:
        changed = False
        for t in doc:
            if t.dep_ == "conj" and t.head in pred_tokens and t.pos_ in {"VERB", "AUX"}:
                if t not in pred_tokens:
                    pred_tokens.append(t)
                    changed = True

    def pred_text(p):
        parts = {p}
        for ch in p.children:
            if ch.dep_ in {"aux", "auxpass", "cop", "neg"}:
                parts.add(ch)
            if ch.dep_ == "xcomp" and ch.pos_ in {"VERB", "AUX"}:
                parts.add(ch)
        return " ".join(tok.text for tok in sorted(parts, key=lambda x: x.i))

    def subjects(p):
        subs = [ch for ch in p.children if ch.dep_ in {"nsubj", "nsubjpass", "nsubj:pass"}]
        if subs:
            return subs
        if p.dep_ == "conj":
            return subjects(p.head)
        return []

    all_subj = []
    all_pred = []
    for p in sorted(pred_tokens, key=lambda x: x.i):
        all_pred.append(pred_text(p))
        all_subj.extend([s.text for s in subjects(p)])

    return all_subj, all_pred

# %%
print("Russian sentences")
for text in russian_sentences:
    doc = nlp_ru(text)
    subject, predicate = find_subj_pred_rus(doc)
    print(f"Предложение: {text}")
    print(f"Подлежащее: {subject}, Сказуемое: {predicate}")
    print()
# Out:
# Russian sentences
# Предложение: Он вышел на улицу.
# Подлежащее: ['Он'], Сказуемое: ['вышел']
#
# Предложение: Мы купили шоколад.
# Подлежащее: ['Мы'], Сказуемое: ['купили']
#
# Предложение: Мы хотели пирога, но яблоки еще не созрели.
# Подлежащее: ['Мы', 'яблоки'], Сказуемое: ['хотели', 'созрели']
#
# Предложение: Мне было сложно понять, как ей удалось так быстро привыкнуть к новому городу.
# Подлежащее: [], Сказуемое: ['было сложно']
#
# Предложение: Я был рад, что всё хорошо закончилось.
# Подлежащее: ['Я'], Сказуемое: ['был рад']

# %%
print("\nПоиск пар слов, связанных отношением определения (прилагательное-существительное) (русский):")
for sentence in russian_sentences:
    doc_ru = nlp_ru(sentence)
    for token in doc_ru:
        if token.dep_ == "amod":
            print(f"Найден объект: {token.text} — зависит от существительного: {token.head.text}")
# Out:
# Поиск пар слов, связанных отношением определения (прилагательное-существительное) (русский):
# Найден объект: новому — зависит от существительного: городу

# %%
print("\nПоиск пар слов, связанных отношением определения (прилагательное-существительное) (english):")
for sentence in english_sentences:
    doc_en = nlp_en(sentence)
    for token in doc_en:
        if token.dep_ == "amod":
            print(f"Найден объект: {token.text} — зависит от существительного: {token.head.text}")
# Out:
# Поиск пар слов, связанных отношением определения (прилагательное-существительное) (english):
# Найден объект: expensive — зависит от существительного: chocolate

# %%
# Функция для извлечения всех объектных и субъектных отношений из предложения в формате (субъект, предикат, объект)
def get_svo(sentence, lang='en'):
    if lang == 'rus':
        doc = nlp_ru(sentence)
        for token in doc:
            if token.dep_ == "nsubj":
                subj = token.text
            if token.dep_ == "obj":
                obj = token.text
                predicate = token.head.text
                print(f"{subj} {predicate} {obj} ")
    else:
        doc = nlp_en(sentence)
        for token in doc:
            if token.dep_ in {"nsubj", "nsubjpass", "csubj", "csubjpass"}:
                subj = token.text
                predicate = token.head.text
            if token.dep_ in {"dobj", "iobj", "obj"}:
                obj = token.text
                print(f"{subj} {predicate} {obj}")

print("Русское SVO")
print(20 * '*')
for sentence in russian_sentences:
    get_svo(sentence, 'rus')

print("\nАнглийское SVO")
print(20 * '*')
for sentence in english_sentences:
    get_svo(sentence, 'en')
# Out:
# Русское SVO
# ********************
# Мы купили шоколад
# Мы хотели пирога
#
# Английское SVO
# ********************
# We bought chocolate

# %% [markdown]
# **Задание 4: Распознавание именованных сущностей (Named Entity Recognition)**

# %% [markdown]
# 1. Подготовьте корпус из 10 новостных текстов, содержащий различные типы именованных сущностей (имена людей, организации, географические названия, даты и т.д.) на английском или русском языке.
# 2. Используйте SpaCy для автоматического распознавания именованных сущностей.
# 3. Реализуйте свой простой метод для распознавания имен людей и географических названий с помощью регулярных выражений и словарей.
# 4. Сравните результаты работы SpaCy и вашего метода:
# * Рассчитайте точность (precision), полноту (recall) и F1-меру для вашего метода относительно результатов SpaCy
# * Проанализируйте ошибки обоих подходов, какие типы ошибок характерны для каждого подхода
#
# **Ответ:**
#
# 5. Представьте сравнение результатов в виде таблицы

# %%
# ваш код
news_text = "news.txt"

# Reading text
with open(news_text, 'r', encoding='utf-8') as file:
    news_text = file.read()
print(f"Файл успешно прочитан. Длина текста: {len(news_text)} символов")
# Out:
# Файл успешно прочитан. Длина текста: 46857 символов

# %%
def spacy_ner(text, language='english'):
    """
    Распознавание именованных сущностей с помощью spaCy
    """

    doc = nlp_en(news_text)

    # Извлечение сущностей
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    return entities

entities_spacy = spacy_ner(text)
for entity, entity_type in entities_spacy:
        print(f"- {entity}: {entity_type}")
# Out:
# - European Union: ORG
# - European Union: ORG
# - Sunday: DATE
# - 27: CARDINAL
# - Brussels: GPE
# - later this week: DATE
# - Trump: PERSON
# - Greenland: GPE
# - European Union: ORG
# - Sunday: DATE
# - Trump: PERSON
# - Saturday: DATE
# - Greenland: GPE
# - European: NORP
# - 10 percent: PERCENT
# - February: DATE
# - up to 25 percent: PERCENT
# - June: DATE
# - Sunday: DATE
# - 27: CARDINAL
# - Brussels: GPE
# - Greenland: GPE
# - Denmark: GPE
# - Trump: ORG
# - NBC: ORG
# - Meet the Press: WORK_OF_ART
# - Treasury: ORG
# - Scott Bessent: PERSON
# - European: NORP
# - American: NORP
# - Greenland: GPE
# - Greenland: GPE
# - Europe: LOC
# - the United States: GPE
# - European: NORP
# - Bessent: PERSON
# - Washington: GPE
# - European: NORP
# - two: CARDINAL
# - 93 billion euros: MONEY
# - $107 billion: MONEY
# - last year’s: DATE
# - February: DATE
# - the European Parliament: ORG
# - Emmanuel Macron: PERSON
# - French: NORP
# - the European Union: ORG
# - Europe: LOC
# ...

# %%
def rule_based(text):
    """
    Улучшенная реализация распознавания именованных сущностей на основе правил
    """

    entities = []

    # Токенизация текста
    words = word_tokenize(text, language='english')



    date_patterns = [
        r'\d{1,2}\s(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}',
        r'\d{1,2}\s(?:января|февраля|марта|апреля|мая|июня|июля|августа|сентября|октября|ноября|декабря)\s\d{4}',
        r'\d{1,2}/\d{1,2}/\d{4}',
        r'\d{1,2}\.\d{1,2}\.\d{4}'
    ]

    money_patterns = [
        r'\$\d+(?:,\d+)*(?:\.\d+)?',
        r'\d+(?:,\d+)*(?:\.\d+)?\s(?:USD|EUR|GBP|RUB|руб\.|долларов|евро)',
        r'\d+\s(?:млн|млрд|тыс\.)\s(?:USD|EUR|GBP|RUB|руб\.|долларов|евро)'
    ]
    # Проценты
    percent_patterns = [
        # 10%, 10.5%, 10,5 %, 100 %
        r'\b\d{1,3}(?:[.,]\d+)?\s?%',

        # 10–12%, 10-12 %, 10,5–11,2%
        r'\b\d{1,3}(?:[.,]\d+)?\s?(?:[-–—]\s?\d{1,3}(?:[.,]\d+)?)\s?%',

        # 10 процентов / 10 процента / 10 процент / 10 pct / 10 percent
        r'(?i)\b\d{1,3}(?:[.,]\d+)?\s?(?:проц(?:ент(?:а|ов)?)?|pct|percent)\b',
    ]

    # Адреса электронной почты
    email_patterns = [
        r'(?i)\b[a-z0-9._%+-]+@[a-z0-9.-]+\.[a-z]{2,}\b',

        r'(?i)\b[\w.!#$%&\'*+/=?^`{|}~-]+@[\w-]+(?:\.[\w-]+)+\b',
    ]

    # URL
    url_patterns = [
        # http(s)://..., ftp://..., www....
        r'(?i)\b(?:https?://|ftp://|www\.)[^\s<>"\']+',

        # домены без схемы: example.com, example.co.uk/path?x=1
        r'(?i)\b(?:[a-z0-9-]+\.)+[a-z]{2,}(?:/[^\s<>"\']*)?',
    ]

    # Телефоны
    phone_patterns = [
    r'\+\d{10,15}\b',
    r'(?i)(?:(?=(?:\D*\d){7,15}\D*$)\+?\d[\d\s().-]{6,}\d)(?:\s?(?:доб\.?|ext\.?|x)\s?\d{1,5})?',
    r'(?i)(?:(?:\+7|8)\s?\(?\d{3}\)?\s?\d{3}[-\s]?\d{2}[-\s]?\d{2})(?:\s?(?:доб\.?|ext\.?|x)\s?\d{1,5})?',
    ]

    # 2. Расширьте словари
    person_prefixes = {
        "Mr.", "Mr", "Mrs.", "Mrs", "Ms.", "Ms", "Mx.", "Mx",
        "Dr.", "Dr", "Prof.", "Prof",
        "Sir", "Dame", "Lord", "Lady",
        "President", "Vice", "Prime", "Minister", "PM", "Chancellor",
        "Sen.", "Sen", "Rep.", "Rep", "Gov.", "Gov", "Mayor",
        "General", "Gen.", "Gen", "Colonel", "Col.", "Col", "Major", "Maj.", "Maj",
        "Captain", "Capt.", "Capt", "Lt.", "Lt", "Admiral", "Adm.", "Adm",
        "King", "Queen", "Prince", "Princess",
        "Sheikh", "Imam", "Rabbi", "Father", "Sister", "Brother",
    }

    location_prefixes = {
        "in", "at", "from", "to", "near", "inside", "outside", "around", "within",
        "into", "onto", "towards", "via", "between", "across", "over", "under",
        "through", "behind", "beside", "by", "along",
    }


    organizations = {
        # Tech / Internet
        "Apple", "Google", "Alphabet", "Microsoft", "IBM", "Meta", "Facebook", "Instagram", "WhatsApp",
        "Amazon", "AWS", "Netflix", "OpenAI", "Tesla", "SpaceX", "Intel", "AMD", "NVIDIA", "Oracle",
        "SAP", "Adobe", "Salesforce", "Samsung", "Sony", "LG", "Huawei", "Xiaomi",
        "Tencent", "Alibaba", "ByteDance", "Baidu", "TSMC", "Uber", "Airbnb", "Stripe", "Shopify",

        # Finance
        "Visa", "Mastercard", "PayPal", "JPMorgan", "Goldman", "Morgan", "HSBC", "Deutsche", "Barclays",
        "BlackRock", "Citigroup", "Bank", "America",

        # Industry / Auto / Aerospace
        "Shell", "BP", "ExxonMobil", "Chevron", "TotalEnergies", "Siemens", "Bosch",
        "Toyota", "Volkswagen", "BMW", "Mercedes-Benz", "Airbus", "Boeing",

        # Institutions
        "UN", "EU", "NATO", "WHO", "UNICEF", "UNESCO", "IMF", "Interpol", "NASA", "ESA", "FBI", "CIA",
        "OECD", "WTO",
    }



    known_people = {
        # Tech / business
        "Elon Musk", "Steve Jobs", "Bill Gates", "Satya Nadella", "Sundar Pichai", "Tim Cook",
        "Mark Zuckerberg", "Jeff Bezos", "Sam Altman", "Jensen Huang", "Larry Page", "Sergey Brin",
        "Warren Buffett", "Oprah Winfrey", "Richard Branson", "Jack Ma",

        # Politics / public figures
        "Barack Obama", "Joe Biden", "Donald Trump", "Kamala Harris",
        "Angela Merkel", "Emmanuel Macron", "Justin Trudeau",
        "Narendra Modi", "Xi Jinping", "Volodymyr Zelenskyy",
        "Benjamin Netanyahu", "Pope Francis", "King Charles", "Queen Elizabeth",
        "Greta Thunberg", "Malala Yousafzai",

        # Science / history
        "Albert Einstein", "Isaac Newton", "Marie Curie", "Stephen Hawking", "Alan Turing",
        "Nikola Tesla", "Charles Darwin", "Ada Lovelace",
        "Nelson Mandela", "Martin Luther King", "Mahatma Gandhi", "Winston Churchill",

        # Entertainment
        "Taylor Swift", "Beyonce", "Beyoncé", "Rihanna", "Adele", "Lady Gaga", "Ariana Grande",
        "Drake", "Ed Sheeran", "The Weeknd", "Billie Eilish", "Harry Styles", "Justin Bieber",
        "Leonardo DiCaprio", "Brad Pitt", "Angelina Jolie", "Tom Cruise", "Scarlett Johansson",
        "Jennifer Lawrence", "Dwayne Johnson", "Robert Downey", "Keanu Reeves", "Meryl Streep",

        # Sports
        "Lionel Messi", "Cristiano Ronaldo", "Michael Jordan", "Serena Williams",
        "LeBron James", "Roger Federer", "Rafael Nadal", "Novak Djokovic",
        "Lewis Hamilton", "Tiger Woods",
    }

    # 3. Реализуйте контекстное распознавание
    # Поиск дат
    for pattern in date_patterns:
        for match in re.finditer(pattern, text):
            entities.append((match.group(), 'DATE'))

    # Поиск денежных сумм
    for pattern in money_patterns:
        for match in re.finditer(pattern, text):
            entities.append((match.group(), 'MONEY'))

    # Поиск процентов
    for pattern in percent_patterns:
        for match in re.finditer(pattern, text):
            entities.append((match.group(), 'PERCENT'))

    # Поиск адреса электронной почты
    for pattern in email_patterns:
        for match in re.finditer(pattern, text):
            entities.append((match.group(), 'EMAIL'))

    # Поиск URL
    for pattern in url_patterns:
        for match in re.finditer(pattern, text):
            entities.append((match.group(), 'URL'))

    # Поиск номера
    for pattern in phone_patterns:
        for match in re.finditer(pattern, text):
            entities.append((match.group(), 'PHONE'))

    # Поиск людей, мест и организаций
    i = 0
    while i < len(words):
        # Поиск людей
        if i < len(words) - 1 and words[i] in person_prefixes:
            # Если слово после префикса начинается с заглавной буквы
            if words[i+1][0].isupper():
                # Собираем полное имя
                name_parts = []
                j = i + 1
                while j < len(words) and words[j][0].isupper() and words[j] not in string.punctuation:
                    name_parts.append(words[j])
                    j += 1
                if name_parts:
                    entities.append((' '.join([words[i]] + name_parts), 'PERSON'))
                    i = j
                    continue

        # Поиск организаций
        if words[i] in organizations:
            entities.append((words[i], 'ORGANIZATION'))

        # Поиск знаменитостей
        if words[i] in known_people:
            entities.append((words[i], 'FAMOUS'))

        # Поиск мест
        if i < len(words) - 1 and words[i] in location_prefixes:
            if words[i+1][0].isupper():
                entities.append((words[i+1], 'LOCATION'))

        i += 1

    return entities

# %%
# Методы NER (правила)
rule_entities = rule_based(news_text)

print("\nEnglish parallel text:")
for entity, entity_type in rule_entities:
    print(f"- {entity}: {entity_type}")
# Out:
# English parallel text:
# - $107: MONEY
# - $312: MONEY
# - $1: MONEY
# - $128,000: MONEY
# - 100%: PERCENT
# - 5.5%: PERCENT
# - 23%: PERCENT
# - 72%: PERCENT
# - 24%: PERCENT
# - 58%: PERCENT
# - 10 percent: PERCENT
# - 25 percent: PERCENT
# - Greenland.Credit: URL
# - Character.AI: URL
# - Grok.com: URL
# - Brussels: LOCATION
# - President: LOCATION
# - President Trump: PERSON
# - Mr. Trump: PERSON
# - February: LOCATION
# - June: LOCATION
# - Brussels: LOCATION
# - Mr. Bessent: PERSON
# - February: LOCATION
# - Nuuk: LOCATION
# - President Trump: PERSON
# - Greenland.Credit: LOCATION
# - Brussels: LOCATION
# - Mr.: LOCATION
# - Mr. Trump: PERSON
# - Davos: LOCATION
# - Mr. Trump: PERSON
# - America: ORGANIZATION
# - NATO: ORGANIZATION
# - Europe: LOCATION
# - Prime Minister Keir Starmer: PERSON
# - Mr.: LOCATION
# - Mr. Trump: PERSON
# - NATO: ORGANIZATION
# - Mr.: LOCATION
# - Mr. Trump: PERSON
# - NATO: ORGANIZATION
# - Mr. Trump: PERSON
# - Mr. Trump: PERSON
# ...

# %%
def evaluate_ner(predicted, gold_standard):
    """
    Оценка качества NER с помощью F-меры

    Аргументы:
        predicted: список кортежей (текст, тип) - предсказания модели
        gold_standard: список кортежей (текст, тип) - золотой стандарт

    Возвращает:
        precision, recall, f1: точность, полнота, F1-мера
    """
    # Преобразуем списки в множества для удобства сравнения
    predicted_set = set(predicted)
    gold_set = set(gold_standard)

    # Рассчитываем истинно положительные, ложно положительные и ложно отрицательные
    true_positives = len(predicted_set.intersection(gold_set))
    false_positives = len(predicted_set - gold_set)
    false_negatives = len(gold_set - predicted_set)

    # Рассчитываем точность, полноту и F1-меру
    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0

    return precision, recall, f1

# %%
# Функция для вывода результатов оценки
def print_evaluation_results(method_name, precision, recall, f1):
    print(f"\nРезультаты для {method_name}:")
    print('-' * 50)
    print(f"Точность (Precision): {precision:.4f}")
    print(f"Полнота (Recall): {recall:.4f}")
    print(f"F1-мера: {f1:.4f}")

# %%
gold_standard = [
    ("TechCrunch Disrupt", "ORGANIZATION"),
    ("Jyoti Bansal", "PERSON"),
    ("Medha Agarwal", "PERSON"),
    ("Defy", "ORGANIZATION"),
    ("Jennifer Neundorfer", "PERSON"),
    ("January Ventures", "ORGANIZATION"),
    ("Disrupt 2026", "ORGANIZATION"),
    ("Google Cloud", "ORGANIZATION"),
    ("Netflix", "ORGANIZATION"),
    ("Microsoft", "ORGANIZATION"),
    ("Box", "ORGANIZATION"),
    ("Phia", "ORGANIZATION"),
    ("a16z", "ORGANIZATION"),
    ("ElevenLabs", "ORGANIZATION"),
    ("Wayve", "ORGANIZATION"),
    ("Hugging Face", "ORGANIZATION"),
    ("Elad Gil", "PERSON"),
    ("Vinod Khosla", "PERSON"),
    ("San Francisco", "LOCATION"),
    ("October 13-15, 2026", "DATE"),
    ("TechCrunch", "ORGANIZATION"),
    ("LTK CEO", "TITLE"),
    ("Amber Venz Box", "PERSON"),
    ("LTK", "ORGANIZATION"),
    ("Patreon CEO", "TITLE"),
    ("Jack Conte", "PERSON"),
    ("Patreon", "ORGANIZATION"),
    ("Northwestern University", "ORGANIZATION"),
    ("21%", "PERCENT"),
    ("97%", "PERCENT"),
    ("Sean Atkins", "PERSON"),
    ("CEO of short-form video production company Dhar Mann Studios", "TITLE"),
    ("Dhar Mann Studios", "ORGANIZATION"),
    ("Eric Wei", "PERSON"),
    ("cofounder of Karat Financial", "TITLE"),
    ("Karat Financial", "ORGANIZATION"),
    ("Discord", "ORGANIZATION"),
    ("Drake", "PERSON"),
    ("Kai Cenat", "PERSON"),
    ("top Twitch streamer", "TITLE"),
    ("Twitch", "ORGANIZATION"),
    ("Glenn Ginsburg", "PERSON"),
    ("president of QYOU Media", "TITLE"),
    ("QYOU Media", "ORGANIZATION"),
    ("Reed Duchscher", "PERSON"),
    ("founding CEO of Night", "TITLE"),
    ("Night", "ORGANIZATION"),
    ("MrBeast", "PERSON"),
    ("Merriam-Webster", "ORGANIZATION"),
    ("94%", "PERCENT"),
    ("Strava", "ORGANIZATION"),
    ("LinkedIn", "ORGANIZATION"),
    ("Substack", "ORGANIZATION"),
    ("PewDiePie", "PERSON"),
    ("Charli D’Amelio", "PERSON"),
    ("Alix Earle", "PERSON"),
    ("Outdoor Boys", "ORGANIZATION"),
    ("Epic Gardening", "ORGANIZATION"),
    ("YouTube", "ORGANIZATION"),
    ("United States", "LOCATION"),
    ("2025", "DATE"),
    ("OpenAI", "ORGANIZATION"),
    ("$40 billion", "MONEY"),
    ("$300 billion", "MONEY"),
    ("Safe Superintelligence", "ORGANIZATION"),
    ("Thinking Machine Labs", "ORGANIZATION"),
    ("$2 billion", "MONEY"),
    ("Meta", "ORGANIZATION"),
    ("$15 billion", "MONEY"),
    ("Scale AI", "ORGANIZATION"),
    ("Scale AI CEO", "TITLE"),
    ("Alexandr Wang", "PERSON"),
    ("$1.3 trillion", "MONEY"),
    ("WASHINGTON, DC", "LOCATION"),
    ("JANUARY 21", "DATE"),
    ("OpenAI CEO", "TITLE"),
    ("Sam Altman", "PERSON"),
    ("U.S. President", "TITLE"),
    ("Donald Trump", "PERSON"),
    ("13%", "PERCENT"),
    ("U.S.", "LOCATION"),
    ("California", "LOCATION"),
    ("Texas", "LOCATION"),
    ("Gridcare", "ORGANIZATION"),
    ("Yottar", "ORGANIZATION"),
]

# %%
# Оценка spaCy NER
spacy_precision, spacy_recall, spacy_f1 = evaluate_ner(entities_spacy, gold_standard)

print_evaluation_results("spaCy NER", spacy_precision, spacy_recall, spacy_f1)
# Out:
# Результаты для spaCy NER:
# --------------------------------------------------
# Точность (Precision): 0.0028
# Полнота (Recall): 0.0118
# F1-мера: 0.0045

# %%
# Оценка rule-based NER
rule_precision, rule_recall, rule_f1 = evaluate_ner(rule_entities, gold_standard)

print_evaluation_results("Rule-based", rule_precision, rule_recall, rule_f1)
# Out:
# Результаты для Rule-based:
# --------------------------------------------------
# Точность (Precision): 0.0108
# Полнота (Recall): 0.0118
# F1-мера: 0.0112

# %%
import pandas as pd

# Таблица сравнения
results_df = pd.DataFrame([
    {
        "Method": "spaCy NER",
        "Precision": spacy_precision,
        "Recall": spacy_recall,
        "F1": spacy_f1,
    },
    {
        "Method": "Rule-based",
        "Precision": rule_precision,
        "Recall": rule_recall,
        "F1": rule_f1,
    }
])


results_df[["Precision","Recall","F1"]] = results_df[["Precision","Recall","F1"]].round(4)
results_df
# Out:
#        Method  Precision  Recall      F1
# 0   spaCy NER     0.0028  0.0118  0.0045
# 1  Rule-based     0.0108  0.0118  0.0112
